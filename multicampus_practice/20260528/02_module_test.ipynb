# %%
import pandas as pd
import yfinance as yf
import invest

# %%
hynix = yf.Ticker('000660.KS')
df = hynix.history(period = '10y')
df.head()
# Out:
#                                    Open          High           Low  \
# Date
# 2016-05-30 00:00:00+09:00  25432.094956  25916.935587  25255.789271
# 2016-05-31 00:00:00+09:00  25255.784915  25564.319809  24859.097193
# 2016-06-01 00:00:00+09:00  25432.093524  25564.322780  25035.405757
# 2016-06-02 00:00:00+09:00  25211.707721  25608.395429  24682.790775
# 2016-06-03 00:00:00+09:00  24815.024209  25079.482726  24153.877916
#
#                                   Close   Volume  Dividends  Stock Splits
# Date
# 2016-05-30 00:00:00+09:00  25564.324219  5492886        0.0           0.0
# 2016-05-31 00:00:00+09:00  25299.861328  5414611        0.0           0.0
# 2016-06-01 00:00:00+09:00  25123.558594  3630711        0.0           0.0
# 2016-06-02 00:00:00+09:00  24726.867188  3443745        0.0           0.0
# 2016-06-03 00:00:00+09:00  24330.183594  3680988        0.0           0.0

# %%
# invest 라이브러리 안에 investing class 생성
inv = invest.Investing(df, _col = 'Close', _start = '2016-07-01')

# %%
rtn_df, acc_rtn = inv.boll()

# %%
acc_rtn
# Out:
# np.int64(1)

# %%
inv.bnh()
# Out:
# np.float64(81.64810123755898)

# %%
mmt_df, mmt_rtn = inv.mmt()
# Out:
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# c:\study\multicampus_practice\20260528\invest\momentum\__init__.py:57: RuntimeWarning: divide by zero encountered in scalar divide
#   momentum_index = _df2.loc[i,'BF1'] / _df2.loc[i, 'BF2'] - _score
# 날짜 : 2016-07-29 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2016-08-31 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2016-09-30 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2016-10-31 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2016-11-30 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2016-12-29 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2017-01-31 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2017-02-28 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2017-03-31 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2017-04-28 00:00:00, 모멘텀 인덱스 : inf, signal :
# 날짜 : 2017-05-31 00:00:00, 모멘텀 인덱스 : 0.9065924042784017, signal : buy
# 날짜 : 2017-06-30 00:00:00, 모멘텀 인덱스 : 0.7826901458659308, signal : buy
# 날짜 : 2017-07-31 00:00:00, 모멘텀 인덱스 : 0.985397696020528, signal : buy
# 날짜 : 2017-08-31 00:00:00, 모멘텀 인덱스 : 0.8348152708371477, signal : buy
# 날짜 : 2017-09-29 00:00:00, 모멘텀 인덱스 : 0.7291957006533192, signal : buy
# 날짜 : 2017-10-31 00:00:00, 모멘텀 인덱스 : 1.0488796407206986, signal : buy
# 날짜 : 2017-11-30 00:00:00, 모멘텀 인덱스 : 0.941603285014055, signal : buy
# 날짜 : 2017-12-28 00:00:00, 모멘텀 인덱스 : 0.718121081130366, signal : buy
# 날짜 : 2018-01-31 00:00:00, 모멘텀 인덱스 : 0.44409564634114473, signal : buy
# 날짜 : 2018-02-28 00:00:00, 모멘텀 인덱스 : 0.5954359541048406, signal : buy
# 날짜 : 2018-03-30 00:00:00, 모멘텀 인덱스 : 0.5416248996378998, signal : buy
# 날짜 : 2018-04-30 00:00:00, 모멘텀 인덱스 : 0.5261796729170631, signal : buy
# 날짜 : 2018-05-31 00:00:00, 모멘텀 인덱스 : 0.5027636482704241, signal : buy
# 날짜 : 2018-06-29 00:00:00, 모멘텀 인덱스 : 0.40473946982191, signal : buy
# 날짜 : 2018-07-31 00:00:00, 모멘텀 인덱스 : 0.31627233956503265, signal : buy
# 날짜 : 2018-08-31 00:00:00, 모멘텀 인덱스 : 0.27525018113454536, signal : buy
# 날짜 : 2018-09-28 00:00:00, 모멘텀 인덱스 : 0.014921634962267394, signal : buy
# 날짜 : 2018-10-31 00:00:00, 모멘텀 인덱스 : -0.09852350664246456, signal :
# 날짜 : 2018-11-30 00:00:00, 모멘텀 인덱스 : -0.0998146721277311, signal :
# 날짜 : 2018-12-28 00:00:00, 모멘텀 인덱스 : -0.09019597913949806, signal :
# 날짜 : 2019-01-31 00:00:00, 모멘텀 인덱스 : -0.1558010291587143, signal :
# 날짜 : 2019-02-28 00:00:00, 모멘텀 인덱스 : -0.013130057864508937, signal :
# 날짜 : 2019-03-29 00:00:00, 모멘텀 인덱스 : -0.11695201120061616, signal :
# 날짜 : 2019-04-30 00:00:00, 모멘텀 인덱스 : -0.09941659890373111, signal :
# 날짜 : 2019-05-31 00:00:00, 모멘텀 인덱스 : -0.1325246069488344, signal :
# 날짜 : 2019-06-28 00:00:00, 모멘텀 인덱스 : -0.2185356458057025, signal :
# 날짜 : 2019-07-31 00:00:00, 모멘텀 인덱스 : -0.17405519819198534, signal :
# 날짜 : 2019-08-30 00:00:00, 모멘텀 인덱스 : -0.049778016629782096, signal :
# 날짜 : 2019-09-30 00:00:00, 모멘텀 인덱스 : 0.08592627913276085, signal : buy
# 날짜 : 2019-10-31 00:00:00, 모멘텀 인덱스 : 0.23613034368658048, signal : buy
# 날짜 : 2019-11-29 00:00:00, 모멘텀 인덱스 : 0.208318739352799, signal : buy
# 날짜 : 2019-12-30 00:00:00, 모멘텀 인덱스 : 0.3371899398037621, signal : buy
# 날짜 : 2020-01-31 00:00:00, 모멘텀 인덱스 : 0.2869176731525953, signal : buy
# 날짜 : 2020-02-28 00:00:00, 모멘텀 인덱스 : 0.3499542363136774, signal : buy
# 날짜 : 2020-03-31 00:00:00, 모멘텀 인덱스 : 0.19726602380630887, signal : buy
# 날짜 : 2020-04-29 00:00:00, 모멘텀 인덱스 : 0.06567145011518649, signal : buy
# 날짜 : 2020-05-29 00:00:00, 모멘텀 인덱스 : 0.29544148702087725, signal : buy
# 날짜 : 2020-06-30 00:00:00, 모멘텀 인덱스 : 0.18516338412026578, signal : buy
# 날짜 : 2020-07-31 00:00:00, 모멘텀 인덱스 : 0.11842991215287313, signal : buy
# 날짜 : 2020-08-31 00:00:00, 모멘텀 인덱스 : 0.08117246409685741, signal : buy
# 날짜 : 2020-09-29 00:00:00, 모멘텀 인덱스 : -0.07663467960367776, signal :
# 날짜 : 2020-10-30 00:00:00, 모멘텀 인덱스 : 0.03531111874386261, signal : buy
# 날짜 : 2020-11-30 00:00:00, 모멘텀 인덱스 : -0.0018318120745489663, signal :
# 날짜 : 2020-12-30 00:00:00, 모멘텀 인덱스 : 0.0361315006918137, signal : buy
# 날짜 : 2021-01-29 00:00:00, 모멘텀 인덱스 : 0.2803494709329135, signal : buy
# 날짜 : 2021-02-26 00:00:00, 모멘텀 인덱스 : 0.4078904331979887, signal : buy
# 날짜 : 2021-03-31 00:00:00, 모멘텀 인덱스 : 0.7160629983417544, signal : buy
# 날짜 : 2021-04-30 00:00:00, 모멘텀 인덱스 : 0.5992346966935209, signal : buy
# 날짜 : 2021-05-31 00:00:00, 모멘텀 인덱스 : 0.5866243706795258, signal : buy
# 날짜 : 2021-06-30 00:00:00, 모멘텀 인덱스 : 0.5076341854777302, signal : buy
# 날짜 : 2021-07-30 00:00:00, 모멘텀 인덱스 : 0.5556129345904803, signal : buy
# 날짜 : 2021-08-31 00:00:00, 모멘텀 인덱스 : 0.5133324451760535, signal : buy
# 날짜 : 2021-09-30 00:00:00, 모멘텀 인덱스 : 0.28083193828727127, signal : buy
# 날짜 : 2021-10-29 00:00:00, 모멘텀 인덱스 : 0.30230372855096377, signal : buy
# 날짜 : 2021-11-30 00:00:00, 모멘텀 인덱스 : 0.06722112496355703, signal : buy
# 날짜 : 2021-12-30 00:00:00, 모멘텀 인덱스 : -0.03797459905132339, signal :
# 날짜 : 2022-01-28 00:00:00, 모멘텀 인덱스 : 0.08246226209950458, signal : buy
# 날짜 : 2022-02-28 00:00:00, 모멘텀 인덱스 : -0.13799828481044063, signal :
# 날짜 : 2022-03-31 00:00:00, 모멘텀 인덱스 : -0.060348673347139004, signal :
# 날짜 : 2022-04-29 00:00:00, 모멘텀 인덱스 : -0.06451529014320379, signal :
# 날짜 : 2022-05-31 00:00:00, 모멘텀 인덱스 : -0.10109601328629925, signal :
# 날짜 : 2022-06-30 00:00:00, 모멘텀 인덱스 : -0.14043596365752464, signal :
# 날짜 : 2022-07-29 00:00:00, 모멘텀 인덱스 : -0.1765772931309887, signal :
# 날짜 : 2022-08-31 00:00:00, 모멘텀 인덱스 : -0.06423470470471937, signal :
# 날짜 : 2022-09-30 00:00:00, 모멘텀 인덱스 : -0.05912127191796579, signal :
# 날짜 : 2022-10-31 00:00:00, 모멘텀 인덱스 : -0.1756621826276633, signal :
# 날짜 : 2022-11-30 00:00:00, 모멘텀 인덱스 : -0.25878860513281887, signal :
# 날짜 : 2022-12-29 00:00:00, 모멘텀 인덱스 : -0.3450449028590815, signal :
# 날짜 : 2023-01-31 00:00:00, 모멘텀 인덱스 : -0.36928452196659445, signal :
# 날짜 : 2023-02-28 00:00:00, 모멘텀 인덱스 : -0.2708825792497068, signal :
# 날짜 : 2023-03-31 00:00:00, 모멘텀 인덱스 : -0.23417821031405672, signal :
# 날짜 : 2023-04-28 00:00:00, 모멘텀 인덱스 : -0.2011680991421314, signal :
# 날짜 : 2023-05-31 00:00:00, 모멘텀 인덱스 : -0.1594312128489841, signal :
# 날짜 : 2023-06-30 00:00:00, 모멘텀 인덱스 : 0.20668310006727775, signal : buy
# 날짜 : 2023-07-31 00:00:00, 모멘텀 인덱스 : 0.19293266067228787, signal : buy
# 날짜 : 2023-08-31 00:00:00, 모멘텀 인덱스 : 0.31408771111986455, signal : buy
# 날짜 : 2023-09-27 00:00:00, 모멘텀 인덱스 : 0.48041992467533445, signal : buy
# 날짜 : 2023-10-31 00:00:00, 모멘텀 인덱스 : 0.4044669587862537, signal : buy
# 날짜 : 2023-11-30 00:00:00, 모멘텀 인덱스 : 0.38552521415990837, signal : buy
# 날짜 : 2023-12-28 00:00:00, 모멘텀 인덱스 : 0.8008502168597069, signal : buy
# 날짜 : 2024-01-31 00:00:00, 모멘텀 인덱스 : 0.6162071137911971, signal : buy
# 날짜 : 2024-02-29 00:00:00, 모멘텀 인덱스 : 0.5230495255894192, signal : buy
# 날짜 : 2024-03-29 00:00:00, 모멘텀 인덱스 : 0.7759444000781697, signal : buy
# 날짜 : 2024-04-30 00:00:00, 모멘텀 인덱스 : 1.0631450153367719, signal : buy
# 날짜 : 2024-05-31 00:00:00, 모멘텀 인덱스 : 0.6185272968304343, signal : buy
# 날짜 : 2024-06-28 00:00:00, 모멘텀 인덱스 : 0.6528331146425519, signal : buy
# 날짜 : 2024-07-31 00:00:00, 모멘텀 인덱스 : 0.9311964318075492, signal : buy
# 날짜 : 2024-08-30 00:00:00, 모멘텀 인덱스 : 0.6099263528406471, signal : buy
# 날짜 : 2024-09-30 00:00:00, 모멘텀 인덱스 : 0.5220602422144007, signal : buy
# 날짜 : 2024-10-31 00:00:00, 모멘텀 인덱스 : 0.5114048120433785, signal : buy
# 날짜 : 2024-11-29 00:00:00, 모멘텀 인덱스 : 0.40071093908904154, signal : buy
# 날짜 : 2024-12-30 00:00:00, 모멘텀 인덱스 : 0.13522686519320248, signal : buy
# 날짜 : 2025-01-31 00:00:00, 모멘텀 인덱스 : 0.29694780204415894, signal : buy
# 날짜 : 2025-02-28 00:00:00, 모멘텀 인덱스 : 0.2811465579544068, signal : buy
# 날짜 : 2025-03-31 00:00:00, 모멘텀 인덱스 : 0.04912965076264686, signal : buy
# 날짜 : 2025-04-30 00:00:00, 모멘텀 인덱스 : 0.10502517300033465, signal : buy
# 날짜 : 2025-05-30 00:00:00, 모멘텀 인덱스 : -0.053006753796101314, signal :
# 날짜 : 2025-06-30 00:00:00, 모멘텀 인덱스 : -0.1266960230693377, signal :
# 날짜 : 2025-07-31 00:00:00, 모멘텀 인덱스 : 0.5154558264431583, signal : buy
# 날짜 : 2025-08-29 00:00:00, 모멘텀 인덱스 : 0.5902330608343633, signal : buy
# 날짜 : 2025-09-30 00:00:00, 모멘텀 인덱스 : 0.5556692189587535, signal : buy
# 날짜 : 2025-10-31 00:00:00, 모멘텀 인덱스 : 0.8834375859531083, signal : buy
# 날짜 : 2025-11-28 00:00:00, 모멘텀 인덱스 : 2.5299830934010443, signal : buy
# 날짜 : 2025-12-30 00:00:00, 모멘텀 인덱스 : 2.079615550501686, signal : buy
# 날짜 : 2026-01-30 00:00:00, 모멘텀 인덱스 : 2.302264480517062, signal : buy
# 날짜 : 2026-02-27 00:00:00, 모멘텀 인덱스 : 3.798161035809885, signal : buy
# 날짜 : 2026-03-31 00:00:00, 모멘텀 인덱스 : 4.596117209396329, signal : buy
# 날짜 : 2026-04-30 00:00:00, 모멘텀 인덱스 : 3.572958762898466, signal : buy
# 날짜 : 2026-05-29 00:00:00, 모멘텀 인덱스 : 5.3137304938789836, signal : buy
# 매수일 : 2017-05-31 00:00:00, 매수가격 : 50916.3359375
# 매도일 : 2018-10-31 00:00:00, 매도가 : 61755.484375, 수익율 : 1.2128815484838715
# 매수일 : 2019-09-30 00:00:00, 매수가격 : 76337.828125
# 매도일 : 2020-09-29 00:00:00, 매도가 : 78841.109375, 수익율 : 1.0327921465868923
# 매수일 : 2020-10-30 00:00:00, 매수가격 : 74992.8984375
# 매도일 : 2020-11-30 00:00:00, 매도가 : 91511.9921875, 수익율 : 1.2202754406641212
# 매수일 : 2020-12-30 00:00:00, 매수가격 : 112360.46875
# 매도일 : 2021-12-30 00:00:00, 매도가 : 125731.484375, 수익율 : 1.119001066600659
# 매수일 : 2022-01-28 00:00:00, 매수가격 : 115653.7734375
# 매도일 : 2022-02-28 00:00:00, 매도가 : 118053.2265625, 수익율 : 1.0207468641418491
# 매수일 : 2023-06-30 00:00:00, 매수가격 : 112726.9453125
# 매도일 : 2025-05-30 00:00:00, 매도가 : 203649.015625, 수익율 : 1.806569095440732
# 매수일 : 2025-07-31 00:00:00, 매수가격 : 272361.875

# %%
mmt_rtn
# Out:
# np.float64(3.154222448370807)
