# %% [markdown]
# #### 웹 크롤링
# - 라이브러리
#     - requests
#         - 웹 서버에 요청을 보내고 응답을 받는 기능
#         - 응답 데이터는 bytes, string 형으로 들어온다
#     - bs4
#         - BeautifulSoup class 이용
#         - html로 이루어진 문자 데이터를 pasing 작업을 통해서 데이터의 타입을 변경하여 내부의 데이터에 쉽게 접근하여 추출하기 위한 기능
#             - `"<html><body><p>Text</p></body></html>"` -> 태그를 기준으로 데이터에 접근할수있는 함수들이 존재
#         - 웹의 기본 구조를 파악을 하고 사용을 하면 조금 더 쉽게 접근 가능
#             - 태그 별 속성의 값
#             - 태그의 특징
#     - selenium
#         - 웹 어플리케이션을 테스트하기 위한 라이브러리
#         - 웹 브라우저(chrome, ...)를 python code를 이용하여 제어
#             - 함수를 이용해서 특정 버튼을 클릭
#             - 특정 위치에 데이터를 입력
#
#         - 구글 크롬의 버전이 구버전인 경우 별도의 소프트웨어를 설치가 필요
# - 데이터를 불법적으로 가지고 오는 방법( 합법 / 위법 사이 )
#     - 사이트들마다 크롤링이 가능한 주소들은 지정
#     - 상업적인 용도가 아닌 수업에서의 내용은 큰 지장 X

# %%
# 라이브러리 설치
# !pip install bs4 selenium

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
# requests 라이브러리를 이용해서 openapi에서는 데이터의 결과물이 xml, json 형태
# https://www.naver.com 에 요청을 보냈을 때 어떤 데이터를 줄것인가?
res = requests.get('https://www.naver.com')
# requests.get() https 프로토콜을 이용해서 요청을 보낼 때 에러가 발생하는 경우 -> http

# %%
res.content
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_260205.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"\xec\x9d\xb5\xec\x8a\xa4\xec\x8a\xa4\xec\x9a\xb0 \xec\x97\xb0\xec\x8a\xb5\xed\x95\x98\xea\xb8\xb0 ( \xeb\x82\x9c\xec\x9d\xb4\xeb\x8f\x84 : \xeb\xa7\xa4\xec\x9a\xb0 \xec\x96\xb4\xeb\xa0\xa4\xec\x9b\x80 )","url":"https://chzzk.naver.com/live/c100f81959d1c17044be0541eed56f5b?tracking_code=navermain_game_live","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstre ...

# %%
res.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_260205.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>\nwindow["EAGER-DATA"] = window["EAGER-DATA"] || {};\nwindow["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","blocks":[{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"익스스우 연습하기 ( 난이도 : 매우 어려움 )","url":"https://chzzk.naver.com/live/c100f81959d1c17044be0541eed56f5b?tracking_code=navermain_game_live","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstream%2F27298982%2Flive%2F18476733%2Frecord%2F53042796%2Fthumbnail%2Fimage_480.jpg%3Ftimestamp%3D2026-04-21T14%253A26%22&type=f504_292&service=navermain"},"highlight":"메이플스토리","source":{"name":"피닉스박","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fnng-phinf.pstatic.net%2FMjAyNDAyMDNfMTE3%2FMDAxNzA2OTUxMjkzMjQ4.3B2KxxTyEpzfCKZTKouycd8ZwRn7CmZG8d8TFz9HZhwg.DWNZZLS2JZD5WYVnHijsBForfURuBsaEkqWzLzyLSzog.PNG%2F123.png%22&type=nf96_96&service=navermain"}},"chzzkLiveId":"c100f81959d1c17044be0541eed56f5b","showLiveBadge":true,"_id":"69bb1c3d3b10269462ffbd34"},{"@type":"MATERIAL-PC-FEED","title":"게임탐ㅍ험","url":"https://chzzk.naver.com/live/0d027498b18371674fac3ed17247e6b8?tracking_code=navermain_game_live","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Flivecloud-thumb.akamaized.net%2Fchzzk%2Flivecloud%2FKR%2Fstream%2F26446067%2Flive%2F18474337%2Frecord%2F53039596%2Fthumbnail%2Fimage_480.jpg%3Ftimestamp%3D2026-04-21T14%253A26%22&type=f504_292&service=navermain"},"highlight":"엘소드","sou ...

# %%
html_text = res.text

# %%
# 문자열에서 특정 문자의 위치를 찾는 함수 : find()
html_text.find('네이버')
# Out:
# 378

# %%
html_text[378 : 410]
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
# 문자형태로 이루어진 html 문서를 BeautifulSoup class를 이용해서 객체 변환
# 문자 데이터에서는 특정 영역의 content를 추출하기 어렵다.
# BeautifulSoup에 내장된 함수를 이용해서 데이터를 추출하기 위해 class 생성시 데이터를 대입
soup = bs(html_text, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# - 태그의 이름을 기준으로 검색
#     - soup.태그명
#         - 해당 html 문서 안에서 해당 태그 중 첫번째 태그를 되돌려준다.
#         - 문자열 함수에서 find() 함수와 비슷한 부분
#     - soup.태그명.string
#         - 첫 번째 태그에서 콘텐츠(태그 안에 데이터)를 되돌려준다.
#             - ex) `<p>Test</p>` --> 'Test'
#     - soup.태그명[속성명]
#         - 첫 번째 태그에서 특정 속성의 값을 되돌려준다
#             - ex) `<a href = 'http://www.naver.com'>네이버</a>` -> 'https://www.naver.com`

# %%
soup.a
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.a.string
# Out:
# '상단영역 바로가기'

# %%
soup.a['href']
# Out:
# '#topAsideButton'

# %% [markdown]
# - 내장함수
#     - find()
#         - html 문서 안에서 특정 태그의 첫번째 정보를 출력
#         - find(속성명 = 속성값)
#             - 태그들 중 특정 속성에 특정한 값을 가진 태그의 첫번째 정보를 출력
#         - 함수의 결과 값의 타입은 TAG 데이터의 타입으로 되돌려준다
#     - find_all()
#         - html 문서 안에서 특정 태그의 모든 정보를 출력
#         - limit 매개변수
#             - 찾는 태그의 개수를 지정
#         - 함수의 결과 값의 타입은 ResultSet 타입으로 되돌려준다.
#     - find(), find_all() 함수는 Tag 타입에서는 사용이 가능 // ResultSet에서는 사용이 불가능
#     - ResultSet 타입은 Tag 데이터들이 모여있는 리스트의 형태와 흡사

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
type(soup.find('a'))
# Out:
# bs4.element.Tag

# %%
type(soup.find_all('a'))
# Out:
# bs4.element.ResultSet

# %%
soup.find('a')
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.find_all('a')
# Out:
# [<a href="#topAsideButton"><span>상단영역 바로가기</span></a>,
#  <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a>,
#  <a href="#newsstand"><span>새소식 블록 바로가기</span></a>,
#  <a href="#shopping"><span>쇼핑 블록 바로가기</span></a>,
#  <a href="#feed"><span>관심사 블록 바로가기</span></a>,
#  <a href="#account"><span>MY 영역 바로가기</span></a>,
#  <a href="#widgetboard"><span>위젯 보드 바로가기</span></a>,
#  <a href="#viewSetting"><span>보기 설정 바로가기</span></a>]

# %%
a_tag = soup.find('a')

# %%
a_tag.find('span')
# Out:
# <span>상단영역 바로가기</span>

# %%
a_list = soup.find_all('a')

# %%
# ResultSet는 find(), find_all() 함수 사용이 불가능 -> 에러 발생
# a_list.find('span')

# %%
# 모든 a태그에서 모든 content를 추출하여 새로운 리스트로 생성
# a_list에 있는 첫번째 tag를 선택하여 .string을 이용하여 텍스트 추출( 8번 반복 )
# a_list는 타입이 ResultSet인데 for문에서 바로 사용이 가능할까?
a_datas =[]
for tag_data in a_list:
    # print(tag_data.string)
    # break
    a_datas.append(tag_data.string)
a_datas
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기']

# %%
# map() + lambda
# python에서 기본 제공 map의 결과를 list로 변환
list(
    map(lambda x : x.string,
        a_list
        )
)
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기']

# %%
[ data.string for data in a_list  ]
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기']

# %%
# 네이버 증권 사이트 크롤링

# requests 라이브러리를 이용해서 html문서를 받는다.
result = requests.get('https://finance.naver.com')
# 응답 데이터를 문자형으로 변환 -> BeautifulSoup 파싱
soup = bs(result.text,'html.parser')

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <title>Npay 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="Npay 증권" name="apple-mobile-web-app-title">
# <meta content="Npay 증권" property="og:title">
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="Npay 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/css/finance_header.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/css/finance.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/js/release/common.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/js/nhn.autocomplete.stock.js" type="text/javascript"></script>
# <script>
# 	var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
# </script>
# <!-- smart channel 광고 -->
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
# </script>
# <script type="text/javascript">
# 		(function(){
# 			if (ieVersion === -1 || ieVersion > 10) {
# 				window.gladsdk = window.gladsdk || { cmd: [] };
#
# 				gladsdk.cmd.push(function() {
# 						gladsdk.defineAdSlot({
# 							adUnitId: "p_new_stock",
# 							adSlotElementId: "_SmartChannelTopBanner",
# 							uct: "KR",
# 							customParam: {
# 								calp:
#
#
#
#
#
#
# 									"home"
# 							},
# 						});
#
# 						gladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {
# 							//console.log(gladsdk.event.AD_LOADED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {
# 							//console.log(gladsdk.event.AD_CLICKED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {
# 							//console.log(gladsdk.event.AD_IMPRESSED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {
# 							//TODO: 오류 로깅처리
# 							//console.log(gladsdk.event.ERROR);
# 						});
# 					});
#
# 				gladsdk.cmd.push(function() {
# 					gladsdk.defineAdSlot({
# 						adUnitId: "p_new_stock_top_sidebox",
# 						adSlotElementId: "_SmartChannelTopBannerSidebox",
# 						uct: "KR",
# 						customParam: {
# 							calp:
#
#
#
#
#
#
# 							"home"
# 						},
# 					});
#
# 					gladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {
# 						//console.log(gladsdk.event.AD_LOADED);
# 					});
# 					gladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {
# 						//console.log(gladsdk.event.AD_CLICKED);
# 					});
# 					gladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {
# 						//console.log(gladsdk.event.AD_IMPRESSED);
# 					});
# 					gladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {
# 						//TODO: 오류 로깅처리
# 						//console.log(gladsdk.event.ERROR);
# 					});
# 				});
# 			}
# 		})();
# 	</script>
# <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#     (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
# </meta></meta></head>
# <body onload="getGNB();">
# <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.home";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
# <div id="u_skip">
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#start" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header">
# <div class="header_area">
# <div class="header_inner">
# <div class="logo_area">
# <h1 class="service">
# <a class="logo_link" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 22 22" width="22" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 11C22 13.1756 21.3549 15.3023 20.1462 17.1113C18.9375 18.9202 17.2195 20.3301 15.2095 21.1627C13.1995 21.9952 10.9878 22.2131 8.85401 21.7886C6.72022 21.3642 4.76021 20.3166 3.22183 18.7782C1.68345 17.2398 0.635805 15.2798 0.211368 13.146C-0.213069 11.0122 0.00476298 8.80047 0.837327 6.79048C1.66989 4.78049 3.07979 3.06253 4.88873 1.85383C6.69768 0.645137 8.82441 0 11 0C13.9174 0 16.7153 1.15893 18.7782 3.22183C20.8411 5.28473 22 8.08262 22 11ZM12.8398 5.83V11.3602L8.98976 5.83H5.83V16.1838H9.1575V10.637L13.0075 16.17H16.1783V5.83H12.8398Z" fill="#000"></path>
# </svg>
# <span class="blind">네이버</span>
# </a>
# <a class="logo_link" href="https://new-m.pay.naver.com/" onclick="clickcr(this, 'STA.pay', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 37 22" width="37" xmlns="http://www.w3.org/2000/svg">
# <path d="M34.4319 5.21944L31.3913 12.1478L27.9518 5.21944H25.3072L30.1783 14.8317L28.1703 19.3358H30.7384L37 5.2331L34.4319 5.21944ZM23.6171 15.9331H21.1037V14.9328C20.1894 15.7342 19.0108 16.1685 17.7953 16.1518C14.7901 16.1518 12.4379 13.692 12.4379 10.5763C12.4379 7.46057 14.7874 5.00079 17.7953 5.00079C19.0104 4.9833 20.189 5.41657 21.1037 6.21701V5.21944H23.6171V15.9331ZM21.3987 10.5899C21.3987 8.57019 19.9891 7.03694 18.1204 7.03694C16.2517 7.03694 14.842 8.57019 14.842 10.5899C14.842 12.6097 16.249 14.1429 18.1204 14.1429C19.9918 14.1429 21.3987 12.596 21.3987 10.5899ZM0.00819554 19.3358H2.63088V15.023C3.52823 15.7695 4.66309 16.1699 5.83001 16.1518C8.83516 16.1518 11.1901 13.692 11.1901 10.5763C11.1901 7.46057 8.83789 5.00079 5.83001 5.00079C4.61166 4.9789 3.42899 5.4126 2.51341 6.21701V5.21944H0L0.00819554 19.3358ZM5.51856 7.03694C7.38722 7.03694 8.79691 8.57019 8.79691 10.5899C8.79691 12.6097 7.38722 14.1429 5.51856 14.1429C3.6499 14.1429 2.24021 12.6097 2.24021 10.5899C2.24021 8.57019 3.63351 7.03694 5.51856 7.03694Z" fill="#000"></path>
# </svg>
# <span class="blind">페이</span>
# </a>
# <a class="logo_link" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 34 22" width="34" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.43006 8.88998L1.85406 6.99998C5.29206 6.31598 7.00206 5.34398 7.45206 4.31798H2.71806V2.35598H14.3641V4.31798H9.75606C9.70206 4.65998 9.61206 4.98398 9.46806 5.28998L15.2101 6.98198L14.4901 8.88998L8.02806 6.92798C6.84006 7.75598 5.00406 8.40398 2.43006 8.88998ZM0.612061 11.5V9.53798H16.4521V11.5H0.612061ZM6.53406 12.796H10.5301C13.2301 12.796 14.7961 14.128 14.7961 15.91C14.7961 17.71 13.2301 19.024 10.5301 19.024H6.53406C3.85206 19.024 2.28606 17.71 2.28606 15.91C2.28606 14.128 3.85206 12.796 6.53406 12.796ZM6.96606 17.044H10.1161C11.7901 17.044 12.4921 16.594 12.4921 15.892C12.4921 15.19 11.7901 14.776 10.1161 14.776H6.96606C5.29206 14.776 4.57206 15.19 4.57206 15.892C4.57206 16.594 5.29206 17.044 6.96606 17.044Z" fill="#000"></path>
# <path d="M25.1904 13.354V11.536H29.4564V2.03198H31.7604V15.334H29.4564V13.354H25.1904ZM21.3384 10.564C20.9244 10.582 20.5464 10.582 20.1684 10.582H17.4504L17.3604 8.61998H20.3844C21.5004 8.61998 22.9584 8.56598 24.4884 8.45798C24.7224 6.99998 24.8484 5.63198 24.8664 4.62398H18.4404V2.66198H27.0984V3.56198C27.0984 5.16398 26.9724 6.76598 26.7564 8.25998L28.2684 8.09798L28.5024 10.006C26.9724 10.222 25.2264 10.384 23.5704 10.474C23.4984 11.5 23.3904 12.562 23.2644 13.714L21.0684 13.588C21.1764 12.508 21.2664 11.536 21.3384 10.564ZM22.4724 14.254V16.756H32.3724V18.844H20.1684V14.254H22.4724Z" fill="#000"></path>
# </svg>
# <span class="blind">증권</span>
# </a>
# </h1>
# </div>
# <div class="right_area">
# <div class="search_area">
# <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
# <label class="blind" for="stock_items">증권 종목명·지수명 검색</label>
# <input accesskey="s" autocomplete="off" class="search_input" id="stock_items" name="query" placeholder="종목명·지수명 입력" title="종목명·지수명 검색" type="text"/>
# <input id="_endUrl" name="endUrl" type="hidden" value="">
# <button class="search_button" onclick="clickcr(this, 'STA.search', '', '', event);" type="submit">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6.9999 2.59996C4.56985 2.59996 2.5999 4.56991 2.5999 6.99996C2.5999 9.43002 4.56985 11.4 6.9999 11.4C9.42996 11.4 11.3999 9.43002 11.3999 6.99996C11.3999 4.56991 9.42996 2.59996 6.9999 2.59996ZM1.3999 6.99996C1.3999 3.90717 3.90711 1.39996 6.9999 1.39996C10.0927 1.39996 12.5999 3.90717 12.5999 6.99996C12.5999 10.0928 10.0927 12.6 6.9999 12.6C3.90711 12.6 1.3999 10.0928 1.3999 6.99996Z" fill="#404048" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M10.2421 10.2424C10.4765 10.0081 10.8564 10.0081 11.0907 10.2424L14.424 13.5758C14.6583 13.8101 14.6583 14.19 14.424 14.4243C14.1897 14.6586 13.8098 14.6586 13.5755 14.4243L10.2421 11.091C10.0078 10.8567 10.0078 10.4768 10.2421 10.2424Z" fill="#404048" fill-rule="evenodd"></path>
# </svg>
# <span class="blind">검색</span>
# </button>
# <div class="auto_area">
# <span class="blind">자동완성</span>
# <div id="autoFrame" style="display: none;">
# <div class="wrap" id="atcmp" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <ul class="_resultBox">
# <li>
# <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
# <span class="num _au_real_list">@code@</span>
# <span class="_au_real_list">@txt@</span>
# <span class="type _au_real_list">@market@</span>
# </a>
# <div class="_au_full" style="display:none">@full_txt@</div>
# <div class="_au_code" style="display:none">@in_code@</div>
# <div class="_au_name" style="display:none">@in_name@</div>
# <div class="_au_link" style="display:none">@in_link@</div>
# <div class="_au_market" style="display:none">@in_market@</div>
# </li>
# </ul>
# <div class="search_notice">
# <p class="text">
# 												공모주와 해외 종목은 모바일 페이지로 이동합니다.
# 											</p>
# </div>
# </div>
# </div>
# <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
# <div class="wrap" id="atcmpIng" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												현재 자동완성 기능을 사용하고 계십니다.
# 											</p>
# </div>
# </div>
# </div>
# <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
# <!-- 자동완성 기능이 활성화 -->
# <div class="wrap" id="atcmpStart" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												자동완성 기능이 활성화되었습니다.
# 											</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </input></form>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="EUC-KR" type="text/javascript">
# 							var gnb_service = "finance";
# 							var gnb_template = location.protocol === "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 							var gnb_logout=encodeURIComponent(location.href);
# 							var gnb_brightness = 1;
# 							var gnb_one_naver = 0;
# 						</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20260421" type="text/javascript">
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div id="menu">
# <ul class="menu">
# <li class="m1 first on"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">증권 홈</span><span class="blind">선택됨</span></a></li>
# <li class="m2"><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span></a></li>
# <li class="m3"><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
# <li class="m4"><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
# <li class="m6"><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">리서치</span></a></li>
# <li class="m7"><a href="/news/"><span class="tx">뉴스</span></a></li>
# <li class="m8"><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
# </ul>
# <!-- 새로운 증권보기 버튼 -->
# <div class="area_stock_button">
# <a class="link_new" href="https://stock.naver.com">
# <span class="icon_refresh"></span>
# 						새로운 증권 보기
# 						<span class="icon_new">
# <span class="blind">NEW</span>
# </span>
# </a>
# <span class="tooltip">
# 						더 편리해진 증권을 만나보세요
# 						<span class="icon_arrow"></span>
# </span>
# </div>
# <!-- //새로운 증권보기 버튼 -->
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.stock.naver.com";
# 		if (location.hostname.indexOf("staging-") > -1) {
# 			acDomain = "staging-" + acDomain;
# 		} else if (location.hostname.indexOf("test-") > -1) {
# 			acDomain = "test-" + acDomain;
# 		} else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "xhr", "get", {}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl: [
# 										"https://" + window.location.hostname,
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"],
# 										mobileUrl: "https://m.stock.naver.com"}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock_disable"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = "https://search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object) {
# 			// endUrl check
# 			if (object.endUrl.value) {
# 				if (object.endUrl.value.startsWith("https://m.stock.naver.com")) {
# 					// 검색정보 초기화
# 					var _endUrl = object.endUrl.value;
# 					object.query.value = "";
# 					object.endUrl.value = "";
# 					document.getElementById("atcmp").style.display="none";
# 					window.open(_endUrl, "_blank");
# 				} else {
# 					location.href = object.endUrl.value;
# 				}
#
# 				return;
# 			}
#
# 			// query check
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
# <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0"></iframe>
# </div>
# <div id="wrap">
# <hr/>
# <div class="blind" id="start"><strong name="start">본문시작</strong></div>
# <dl class="blind">
# <dt>오늘의 코스피/코스닥 지수</dt>
# <dd>2026년 04월 21일 장중</dd>
# <dd>코스피 지수 6,374.45 전일대비 상승 155.36 플러스 2.50 퍼센트</dd>
# <dd>코스닥 지수 1,175.93 전일대비 상승 1.08 플러스 0.09 퍼센트</dd>
# </dl>
# <div class="home_spot view_on">
# <div class="bx_spot">
# <div class="tab_spot tab2" id="tab_search">
# <ul>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab1', '000000', 'recent');clickcr(this, 'mys.recent', '', '', event);return false;"><span>최근조회종목</span></a></li>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab2', '000000', 'mystock');clickcr(this, 'mys.interest', '', '', event);return false;"><span>MY STOCK</span></a></li>
# </ul>
# </div>
# <div class="section_tab" id="recent_search_tab">
# <strong class="blind" id="recent_mystock_blind">최근 조회종목 리스트</strong>
# <ul class="tab_list">
# </ul>
# </div>
# <input alt="닫기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.close' : 'mys*i.close'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_close.gif" style="display:none" type="image"/>
# <input alt="펼치기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.open' : 'mys*i.open'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_open.gif" style="display:none" type="image"/>
# </div>
# </div>
# <div class="home" id="container">
# <div id="content">
# <div class="article">
# <div class="section">
# <div class="news_area _replaceNewsLink">
# <div class="section_strategy">
# <h2 class="h_strategy"><span>주요뉴스</span></h2>
# <ul>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=018&amp;article_id=0006262654" onclick="clickcr(this, 'tdn.list', '018_0006262654', '0', event);">내달 22일부터 삼전·닉스 레버리지 ETF 출시 가능</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=119&amp;article_id=0003082903" onclick="clickcr(this, 'tdn.list', '119_0003082903', '1', event);">삼전·하닉 2배 베팅 국내 ETF, 출시일 정해졌다</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=003&amp;article_id=0013900486" onclick="clickcr(this, 'tdn.list', '003_0013900486', '2', event);">불개미 관심 '삼전·닉스 2배 ETF' 내달 22일부터…'陰의 복리' 쓴맛 볼 수도</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=243&amp;article_id=0000096746" onclick="clickcr(this, 'tdn.list', '243_0000096746', '3', event);">외국계 IB들 "코스피, 8500까지 간다…현재 눌려있어"</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=215&amp;article_id=0001249715" onclick="clickcr(this, 'tdn.list', '215_0001249715', '4', event);">'메모리 고속도로' CXL이 온다…기대주 따로 있다는데 [마켓딥다이브]</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=138&amp;article_id=0002225297" onclick="clickcr(this, 'tdn.list', '138_0002225297', '5', event);">국내보다 해외서 더 팔았다…LS일렉트릭, 1분기 역대 최대 실적</a></span>
# </li>
# </ul>
# <a class="btn_more" href="/news/mainnews.naver" onclick="clickcr(this, 'tdn.more', '', '', event);"><em class="btn_more4"><span class="blind">주요뉴스 더보기</span></em></a>
# </div>
# </div>
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <!-- KRX, NXT 탭 -->
# <div class="area_tab_type">
# <ul class="top_tab_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="top_tab_item top_tab_krx is_active">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.krx', '', '', event);return false;">KRX</a>
# </li>
# <li class="top_tab_item top_tab_nxt">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.nxt', '', '', event);return false;">NXT</a>
# </li>
# </ul>
# <div class="text_nxt">
#                                 넥스트레이드(NXT)
#                                 <button class="buttton_tooltip" type="button">
# <span class="icon">
# <span class="blind">도움말</span>
# </span>
# </button>
# <div class="area_tooltip">
# <p>
# <strong>넥스트레이드(NXT)</strong>
#                                         넥스트레이드(NXT)란 대한민국
#                                         최초의 대체거래소(ATS,
#                                         Alternative Trading
#                                         System)입니다. 아래는
#                                         넥스트레이드에서 거래가 가능한
#                                         종목들입니다.
#                                     </p>
# <span class="arrow"></span>
# </div>
# </div>
# </div>
# <!-- //KRX, NXT 탭 -->
# <ul class="tab_sort_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="tab_sort_item is_active"><a class="link tab_sort_sale" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span class="tab1"><span class="blind">거래상위</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_ceiling" href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span class="tab2"><span class="blind">상승</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_bottom" href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span class="tab3"><span class="blind">하락</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_value" href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span class="tab4"><span class="blind">시가총액 상위</span></span></a></li>
# </ul>
# <div class="group_type krx_group_type tab1 is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,396</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 36</td>
# <td>
# <em class="down">
# 				-2.51%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '3', event);">KODEX 2차전지산업레버리지</a></th>
# <td>2,562</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 407</td>
# <td>
# <em class="up">
# 				+18.89%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=047040" onclick="clickcr(this, 'spe.slist', '047040', '4', event);">대우건설</a></th>
# <td>33,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,100</td>
# <td>
# <em class="up">
# 				+18.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.slist', '078130', '5', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 108</td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=065420" onclick="clickcr(this, 'spe.slist', '065420', '6', event);">에스아이리소스</a></th>
# <td>306</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7</td>
# <td>
# <em class="up">
# 				+2.34%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131760" onclick="clickcr(this, 'spe.slist', '131760', '7', event);">파인텍</a></th>
# <td>2,015</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 442</td>
# <td>
# <em class="up">
# 				+28.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=203650" onclick="clickcr(this, 'spe.slist', '203650', '8', event);">드림시큐리티</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 70</td>
# <td>
# <em class="up">
# 				+1.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=184230" onclick="clickcr(this, 'spe.slist', '184230', '9', event);">SGA솔루션즈</a></th>
# <td>1,091</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45</td>
# <td>
# <em class="up">
# 				+4.30%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=530036" onclick="clickcr(this, 'spe.slist', '530036', '10', event);">삼성 인버스 2X WTI원유 선물 ETN</a></th>
# <td>23</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1</td>
# <td>
# <em class="up">
# 				+4.55%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=092220" onclick="clickcr(this, 'spe.slist', '092220', '11', event);">KEC</a></th>
# <td>1,371</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 148</td>
# <td>
# <em class="up">
# 				+12.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.slist', '222080', '12', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,760</td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011930" onclick="clickcr(this, 'spe.slist', '011930', '13', event);">신성이엔지</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 50</td>
# <td>
# <em class="up">
# 				+1.28%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011000" onclick="clickcr(this, 'spe.slist', '011000', '14', event);">진원생명과학</a></th>
# <td>1,418</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 96</td>
# <td>
# <em class="up">
# 				+7.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252710" onclick="clickcr(this, 'spe.slist', '252710', '15', event);">TIGER 200선물인버스2X</a></th>
# <td>192</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 12</td>
# <td>
# <em class="down">
# 				-5.88%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab1 is_active" style="display:none">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems1">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=014940" onclick="clickcr(this, 'spe.slist', '014940', '1', event);">오리엔탈정공</a></th>
# <td>8,510</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 490</td>
# <td>
# <em class="up">
# 				+6.11%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.slist', '005930', '2', event);">삼성전자</a></th>
# <td>218,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,500</td>
# <td>
# <em class="up">
# 				+1.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006360" onclick="clickcr(this, 'spe.slist', '006360', '3', event);">GS건설</a></th>
# <td>42,750</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,700</td>
# <td>
# <em class="up">
# 				+12.35%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=004980" onclick="clickcr(this, 'spe.slist', '004980', '4', event);">성신양회</a></th>
# <td>11,780</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 750</td>
# <td>
# <em class="up">
# 				+6.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=010140" onclick="clickcr(this, 'spe.slist', '010140', '5', event);">삼성중공업</a></th>
# <td>30,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,450</td>
# <td>
# <em class="up">
# 				+5.08%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=378340" onclick="clickcr(this, 'spe.slist', '378340', '6', event);">필에너지</a></th>
# <td>19,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,270</td>
# <td>
# <em class="up">
# 				+19.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=161000" onclick="clickcr(this, 'spe.slist', '161000', '7', event);">애경케미칼</a></th>
# <td>15,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,350</td>
# <td>
# <em class="up">
# 				+9.75%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=077970" onclick="clickcr(this, 'spe.slist', '077970', '8', event);">STX엔진</a></th>
# <td>51,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,800</td>
# <td>
# <em class="up">
# 				+10.39%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'spe.slist', '034020', '9', event);">두산에너빌리티</a></th>
# <td>115,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,400</td>
# <td>
# <em class="up">
# 				+3.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=101730" onclick="clickcr(this, 'spe.slist', '101730', '10', event);">위메이드맥스</a></th>
# <td>6,690</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 170</td>
# <td>
# <em class="up">
# 				+2.61%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005440" onclick="clickcr(this, 'spe.slist', '005440', '11', event);">현대지에프홀딩스</a></th>
# <td>14,960</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 730</td>
# <td>
# <em class="up">
# 				+5.13%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.slist', '336370', '12', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130</td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=028050" onclick="clickcr(this, 'spe.slist', '028050', '13', event);">삼성E&amp;A</a></th>
# <td>51,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,100</td>
# <td>
# <em class="up">
# 				+4.26%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.slist', '107640', '14', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 16,700</td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=114190" onclick="clickcr(this, 'spe.slist', '114190', '15', event);">강원에너지</a></th>
# <td>15,570</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,010</td>
# <td>
# <em class="up">
# 				+6.94%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab2">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=045510" onclick="clickcr(this, 'spe.clist', '045510', '1', event);">정원엔시스</a></th>
# <td>1,297</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 299 </td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.clist', '222080', '2', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 3,760 </td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=036930" onclick="clickcr(this, 'spe.clist', '036930', '3', event);">주성엔지니어링</a></th>
# <td>118,900</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 27,400 </td>
# <td>
# <em class="up">
# 				+29.95%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=256940" onclick="clickcr(this, 'spe.clist', '256940', '4', event);">킵스파마</a></th>
# <td>10,850</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 2,500 </td>
# <td>
# <em class="up">
# 				+29.94%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.clist', '107640', '5', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 16,700 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=312610" onclick="clickcr(this, 'spe.clist', '312610', '6', event);">에이에프더블류</a></th>
# <td>1,424</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 328 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=900100" onclick="clickcr(this, 'spe.clist', '900100', '7', event);">애머릿지</a></th>
# <td>508</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 117 </td>
# <td>
# <em class="up">
# 				+29.92%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=189330" onclick="clickcr(this, 'spe.clist', '189330', '8', event);">씨이랩</a></th>
# <td>8,950</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 2,060 </td>
# <td>
# <em class="up">
# 				+29.90%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=073570" onclick="clickcr(this, 'spe.clist', '073570', '9', event);">리튬포어스</a></th>
# <td>756</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 174 </td>
# <td>
# <em class="up">
# 				+29.90%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=424760" onclick="clickcr(this, 'spe.clist', '424760', '10', event);">벨로크</a></th>
# <td>2,370</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 545 </td>
# <td>
# <em class="up">
# 				+29.86%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.clist', '078130', '11', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 108 </td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131400" onclick="clickcr(this, 'spe.clist', '131400', '12', event);">이브이첨단소재</a></th>
# <td>2,050</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 471 </td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=051980" onclick="clickcr(this, 'spe.clist', '051980', '13', event);">중앙첨단소재</a></th>
# <td>2,135</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 489 </td>
# <td>
# <em class="up">
# 				+29.71%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=127980" onclick="clickcr(this, 'spe.clist', '127980', '14', event);">화인써키트</a></th>
# <td>6,760</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,500 </td>
# <td>
# <em class="up">
# 				+28.52%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.clist', '336370', '15', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130 </td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab2" style="display:none">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.clist', '107640', '1', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 16,700 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.clist', '336370', '2', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130 </td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=378340" onclick="clickcr(this, 'spe.clist', '378340', '3', event);">필에너지</a></th>
# <td>19,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,270 </td>
# <td>
# <em class="up">
# 				+19.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006400" onclick="clickcr(this, 'spe.clist', '006400', '4', event);">삼성SDI</a></th>
# <td>644,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 106,000 </td>
# <td>
# <em class="up">
# 				+19.70%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=348370" onclick="clickcr(this, 'spe.clist', '348370', '5', event);">엔켐</a></th>
# <td>48,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,200 </td>
# <td>
# <em class="up">
# 				+17.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=171090" onclick="clickcr(this, 'spe.clist', '171090', '6', event);">선익시스템</a></th>
# <td>117,300</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 16,400 </td>
# <td>
# <em class="up">
# 				+16.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=469610" onclick="clickcr(this, 'spe.clist', '469610', '7', event);">이노테크</a></th>
# <td>26,550</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,700 </td>
# <td>
# <em class="up">
# 				+16.19%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=443060" onclick="clickcr(this, 'spe.clist', '443060', '8', event);">HD현대마린솔루션</a></th>
# <td>225,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 29,800 </td>
# <td>
# <em class="up">
# 				+15.23%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078600" onclick="clickcr(this, 'spe.clist', '078600', '9', event);">대주전자재료</a></th>
# <td>148,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 18,900 </td>
# <td>
# <em class="up">
# 				+14.54%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=0008Z0" onclick="clickcr(this, 'spe.clist', '0008Z0', '10', event);">에스엔시스</a></th>
# <td>41,050</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,200 </td>
# <td>
# <em class="up">
# 				+14.50%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=009150" onclick="clickcr(this, 'spe.clist', '009150', '11', event);">삼성전기</a></th>
# <td>770,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 90,000 </td>
# <td>
# <em class="up">
# 				+13.24%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=457190" onclick="clickcr(this, 'spe.clist', '457190', '12', event);">이수스페셜티케미컬</a></th>
# <td>126,300</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 14,700 </td>
# <td>
# <em class="up">
# 				+13.17%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006360" onclick="clickcr(this, 'spe.clist', '006360', '13', event);">GS건설</a></th>
# <td>42,750</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,700 </td>
# <td>
# <em class="up">
# 				+12.35%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=323280" onclick="clickcr(this, 'spe.clist', '323280', '14', event);">태성</a></th>
# <td>65,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 6,600 </td>
# <td>
# <em class="up">
# 				+11.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=053610" onclick="clickcr(this, 'spe.clist', '053610', '15', event);">프로텍</a></th>
# <td>73,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,000 </td>
# <td>
# <em class="up">
# 				+10.46%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab3">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=173940" onclick="clickcr(this, 'spe.blist', '173940', '1', event);">에프엔씨엔터</a></th>
# <td>4,140</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -910</td>
# <td>
# <em class="down">
# 				-18.02%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=317120" onclick="clickcr(this, 'spe.blist', '317120', '2', event);">라닉스</a></th>
# <td>2,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -505</td>
# <td>
# <em class="down">
# 				-15.76%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=046970" onclick="clickcr(this, 'spe.blist', '046970', '3', event);">우리로</a></th>
# <td>10,350</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,750</td>
# <td>
# <em class="down">
# 				-14.46%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=338840" onclick="clickcr(this, 'spe.blist', '338840', '4', event);">와이바이오로직스</a></th>
# <td>23,500</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,950</td>
# <td>
# <em class="down">
# 				-14.39%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=215790" onclick="clickcr(this, 'spe.blist', '215790', '5', event);">이노인스트루먼트</a></th>
# <td>2,100</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -345</td>
# <td>
# <em class="down">
# 				-14.11%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=025770" onclick="clickcr(this, 'spe.blist', '025770', '6', event);">한국정보통신</a></th>
# <td>13,680</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,230</td>
# <td>
# <em class="down">
# 				-14.02%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=314130" onclick="clickcr(this, 'spe.blist', '314130', '7', event);">지놈앤컴퍼니</a></th>
# <td>6,070</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -950</td>
# <td>
# <em class="down">
# 				-13.53%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=017900" onclick="clickcr(this, 'spe.blist', '017900', '8', event);">광전자</a></th>
# <td>11,190</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,710</td>
# <td>
# <em class="down">
# 				-13.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=228670" onclick="clickcr(this, 'spe.blist', '228670', '9', event);">레이</a></th>
# <td>8,970</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,360</td>
# <td>
# <em class="down">
# 				-13.17%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=027040" onclick="clickcr(this, 'spe.blist', '027040', '10', event);">서울전자통신</a></th>
# <td>578</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -86</td>
# <td>
# <em class="down">
# 				-12.95%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=356680" onclick="clickcr(this, 'spe.blist', '356680', '11', event);">엑스게이트</a></th>
# <td>14,320</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,120</td>
# <td>
# <em class="down">
# 				-12.90%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=174900" onclick="clickcr(this, 'spe.blist', '174900', '12', event);">앱클론</a></th>
# <td>48,850</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -6,950</td>
# <td>
# <em class="down">
# 				-12.46%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=299660" onclick="clickcr(this, 'spe.blist', '299660', '13', event);">셀리드</a></th>
# <td>3,605</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -505</td>
# <td>
# <em class="down">
# 				-12.29%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=488280" onclick="clickcr(this, 'spe.blist', '488280', '14', event);">에스투더블유</a></th>
# <td>18,980</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,620</td>
# <td>
# ...
# 							} else if (themeTopDetailItem.changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					// 거래상위 (KRX)
# 					jindo.$A(jindo.$$("#_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = topItems[0][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 거래상위 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[0][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 상승 (KRX)
# 					jindo.$A(jindo.$$("#_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = topItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								if (risefall == '1') {
# 									sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 상승 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								if (risefall == '1') {
# 									sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하락 (KRX)
# 					jindo.$A(jindo.$$("#_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = topItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								if (risefall == '4') {
# 									sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하락 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								if (risefall == '4') {
# 									sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
#
# 					// 시가총액 상위 (KRX)
# 					jindo.$A(jindo.$$("#_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = topItems[3][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 시가총액 상위 (NXT)
# 					jindo.$A(jindo.$$("#nxt_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = nxtTopItems[3][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>+" + changeRate.toFixed(2) + "%</td>";
# 							} else if (changeRate < 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 인기 검색 종목
# 					jindo.$A(jindo.$$(".aside_popular tbody tr")).forEach(function(value, index) {
# 						var popularItem = searchList[index];
# 						var uiCount = index + 1;
# 						var changeVal = popularItem.change_val;
# 						var nowVal = popularItem.now_val;
# 						var itemcode = popularItem.itemcode;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th scope=\'row\'><em>" + uiCount + ".</em><a href=\'/item/main.naver?code=" + itemcode + "\' onClick='clickcr(this, \"boa.list\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += cutStringByByte(popularItem.itemname, 12, "..") + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(nowVal) + "</td>";
#
# 						if (popularItem.risefall == 1) {
# 							sHtml += "<td><em class=\'bu_p bu_pup2\'><span class=\'blind\'>상한가</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 2) {
# 							sHtml += "<td><em class=\'bu_p bu_pup'><span class=\'blind\'>상승</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 3) {
# 							sHtml += "<td><span class=\'tah p11\'> 0 </span></td>";
# 						} else if (popularItem.risefall == 4) {
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn2\'><span class=\'blind\'>하한가</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else{
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn'\><span class=\'blind\'>하락</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					startInformationTimer();
# 				}
# 			}
# 		},
# 		timeout : 2,
# 		ontimeout : function() {
# 			startInformationTimer();
# 		},
# 		async : true
# 	});
# 	oUpdateAjax.request();
# }
#
# function getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index) {
# 	values = {
# 			_todayIndexDealTrendLink : todayIndexDealTrendLink[index],
# 			_todayIndexItemUpperLink : "/sise/sise_upper.naver?sosok=" + index,
# 			_todayIndexItemRiseLink : "/sise/sise_rise.naver?sosok=" + index,
# 			_todayIndexItemSteadyLink : "/sise/sise_steady.naver?sosok=" + index,
# 			_todayIndexItemFallLink : "/sise/sise_fall.naver?sosok=" + index,
# 			_todayIndexItemLowerLink : "/sise/sise_lower.naver?sosok=" + index
# 	};
#
# 	return values;
# }
#
# // up, down, same 클래스 생성 기능
# function setUpDownClass(sChangeVal, eValue) {
# 	if (sChangeVal > 0) {
# 		jindo.$Element(eValue).className("up");
# 	} else if (sChangeVal < 0) {
# 		jindo.$Element(eValue).className("down");
# 	} else {
# 		jindo.$Element(eValue).className("same");
# 	}
# }
#
# function setUpDnClass(value){
# 	var className = "";
# 	if (value > 0){
# 		className = "up";
# 	} else if(value < 0){
# 		className = "dn";
# 	}
#
# 	return className;
# }
#
# function mainPageDomReadyFn() {
# 	startInformationTimer();
# 	Polling.init();
# }
#
# function togglePannel(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
# function getOverMarketPriceFormat(tradingSessionType, overMarketPrice) {
# 	if (tradingSessionType == 'PRE_MARKET') {
# 		return "<span class='pre_after_badge'>Pre</span>" + changeNumberFormat(overMarketPrice);
# 	} else if (tradingSessionType == 'AFTER_MARKET') {
# 		return "<span class='pre_after_badge'>After</span>" + changeNumberFormat(overMarketPrice);
# 	} else {
# 		return changeNumberFormat(overMarketPrice);
# 	}
# }
# function removeText(text){
# 	if (text != null) {
# 		return text.toString().replace(/[^0-9|.]/g, '')
# 	}
# 	return text;
# }
# function changeNumberFormat(vNumber){
# 	var sUnderNumber = "";
# 	var sNumberString = vNumber || 0;
# 	sNumberString = (typeof sNumberString != "String") ? String(sNumberString) : sNumberString;
#
# 	if(sNumberString.indexOf(".") > -1){
# 		var aNumber = sNumberString.split(".");
# 		sNumberString = aNumber[0];
# 		sUnderNumber = "." + aNumber[1];
# 	}
#
# 	return sNumberString.replace(/(\d)(?=(\d{3})+$)/igm, "$1,") + sUnderNumber;
# }
#
# // 1분 리플레시, 실시간 시세 폴링, 이미지 리플레시
# jindo.$Fn(mainPageDomReadyFn).attach(document, "domready");
#
# </script>
# </body>
# </html>

# %%
# html문서 안에서 태그명이 div이고 class 속성의 값이 section_sise_top인 태그를 모두 찾아서 길이를 구하자
len(
    soup.find_all(
        'div',
        attrs = {
            'class' : 'section_sise_top'
        }
    )
)
# Out:
# 1

# %%
# 1개 라면 find_all()이 아닌 find() 이용해서 데이터를 추출
div_data = soup.find(
    'div',
    attrs = {
        'class' : 'section_sise_top'
    }
)

# %%
div_data
# Out:
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <!-- KRX, NXT 탭 -->
# <div class="area_tab_type">
# <ul class="top_tab_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="top_tab_item top_tab_krx is_active">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.krx', '', '', event);return false;">KRX</a>
# </li>
# <li class="top_tab_item top_tab_nxt">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.nxt', '', '', event);return false;">NXT</a>
# </li>
# </ul>
# <div class="text_nxt">
#                                 넥스트레이드(NXT)
#                                 <button class="buttton_tooltip" type="button">
# <span class="icon">
# <span class="blind">도움말</span>
# </span>
# </button>
# <div class="area_tooltip">
# <p>
# <strong>넥스트레이드(NXT)</strong>
#                                         넥스트레이드(NXT)란 대한민국
#                                         최초의 대체거래소(ATS,
#                                         Alternative Trading
#                                         System)입니다. 아래는
#                                         넥스트레이드에서 거래가 가능한
#                                         종목들입니다.
#                                     </p>
# <span class="arrow"></span>
# </div>
# </div>
# </div>
# <!-- //KRX, NXT 탭 -->
# <ul class="tab_sort_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="tab_sort_item is_active"><a class="link tab_sort_sale" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span class="tab1"><span class="blind">거래상위</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_ceiling" href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span class="tab2"><span class="blind">상승</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_bottom" href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span class="tab3"><span class="blind">하락</span></span></a></li>
# <li class="tab_sort_item"><a class="link tab_sort_value" href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span class="tab4"><span class="blind">시가총액 상위</span></span></a></li>
# </ul>
# <div class="group_type krx_group_type tab1 is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,396</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 36</td>
# <td>
# <em class="down">
# 				-2.51%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '3', event);">KODEX 2차전지산업레버리지</a></th>
# <td>2,562</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 407</td>
# <td>
# <em class="up">
# 				+18.89%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=047040" onclick="clickcr(this, 'spe.slist', '047040', '4', event);">대우건설</a></th>
# <td>33,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,100</td>
# <td>
# <em class="up">
# 				+18.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.slist', '078130', '5', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 108</td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=065420" onclick="clickcr(this, 'spe.slist', '065420', '6', event);">에스아이리소스</a></th>
# <td>306</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7</td>
# <td>
# <em class="up">
# 				+2.34%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131760" onclick="clickcr(this, 'spe.slist', '131760', '7', event);">파인텍</a></th>
# <td>2,015</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 442</td>
# <td>
# <em class="up">
# 				+28.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=203650" onclick="clickcr(this, 'spe.slist', '203650', '8', event);">드림시큐리티</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 70</td>
# <td>
# <em class="up">
# 				+1.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=184230" onclick="clickcr(this, 'spe.slist', '184230', '9', event);">SGA솔루션즈</a></th>
# <td>1,091</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45</td>
# <td>
# <em class="up">
# 				+4.30%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=530036" onclick="clickcr(this, 'spe.slist', '530036', '10', event);">삼성 인버스 2X WTI원유 선물 ETN</a></th>
# <td>23</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1</td>
# <td>
# <em class="up">
# 				+4.55%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=092220" onclick="clickcr(this, 'spe.slist', '092220', '11', event);">KEC</a></th>
# <td>1,371</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 148</td>
# <td>
# <em class="up">
# 				+12.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.slist', '222080', '12', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,760</td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011930" onclick="clickcr(this, 'spe.slist', '011930', '13', event);">신성이엔지</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 50</td>
# <td>
# <em class="up">
# 				+1.28%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011000" onclick="clickcr(this, 'spe.slist', '011000', '14', event);">진원생명과학</a></th>
# <td>1,418</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 96</td>
# <td>
# <em class="up">
# 				+7.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252710" onclick="clickcr(this, 'spe.slist', '252710', '15', event);">TIGER 200선물인버스2X</a></th>
# <td>192</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 12</td>
# <td>
# <em class="down">
# 				-5.88%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab1 is_active" style="display:none">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems1">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=014940" onclick="clickcr(this, 'spe.slist', '014940', '1', event);">오리엔탈정공</a></th>
# <td>8,510</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 490</td>
# <td>
# <em class="up">
# 				+6.11%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.slist', '005930', '2', event);">삼성전자</a></th>
# <td>218,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,500</td>
# <td>
# <em class="up">
# 				+1.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006360" onclick="clickcr(this, 'spe.slist', '006360', '3', event);">GS건설</a></th>
# <td>42,750</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,700</td>
# <td>
# <em class="up">
# 				+12.35%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=004980" onclick="clickcr(this, 'spe.slist', '004980', '4', event);">성신양회</a></th>
# <td>11,780</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 750</td>
# <td>
# <em class="up">
# 				+6.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=010140" onclick="clickcr(this, 'spe.slist', '010140', '5', event);">삼성중공업</a></th>
# <td>30,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,450</td>
# <td>
# <em class="up">
# 				+5.08%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=378340" onclick="clickcr(this, 'spe.slist', '378340', '6', event);">필에너지</a></th>
# <td>19,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,270</td>
# <td>
# <em class="up">
# 				+19.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=161000" onclick="clickcr(this, 'spe.slist', '161000', '7', event);">애경케미칼</a></th>
# <td>15,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,350</td>
# <td>
# <em class="up">
# 				+9.75%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=077970" onclick="clickcr(this, 'spe.slist', '077970', '8', event);">STX엔진</a></th>
# <td>51,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,800</td>
# <td>
# <em class="up">
# 				+10.39%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'spe.slist', '034020', '9', event);">두산에너빌리티</a></th>
# <td>115,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,400</td>
# <td>
# <em class="up">
# 				+3.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=101730" onclick="clickcr(this, 'spe.slist', '101730', '10', event);">위메이드맥스</a></th>
# <td>6,690</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 170</td>
# <td>
# <em class="up">
# 				+2.61%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005440" onclick="clickcr(this, 'spe.slist', '005440', '11', event);">현대지에프홀딩스</a></th>
# <td>14,960</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 730</td>
# <td>
# <em class="up">
# 				+5.13%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.slist', '336370', '12', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130</td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=028050" onclick="clickcr(this, 'spe.slist', '028050', '13', event);">삼성E&amp;A</a></th>
# <td>51,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,100</td>
# <td>
# <em class="up">
# 				+4.26%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.slist', '107640', '14', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 16,700</td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=114190" onclick="clickcr(this, 'spe.slist', '114190', '15', event);">강원에너지</a></th>
# <td>15,570</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,010</td>
# <td>
# <em class="up">
# 				+6.94%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab2">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=045510" onclick="clickcr(this, 'spe.clist', '045510', '1', event);">정원엔시스</a></th>
# <td>1,297</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 299 </td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.clist', '222080', '2', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 3,760 </td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=036930" onclick="clickcr(this, 'spe.clist', '036930', '3', event);">주성엔지니어링</a></th>
# <td>118,900</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 27,400 </td>
# <td>
# <em class="up">
# 				+29.95%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=256940" onclick="clickcr(this, 'spe.clist', '256940', '4', event);">킵스파마</a></th>
# <td>10,850</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 2,500 </td>
# <td>
# <em class="up">
# 				+29.94%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.clist', '107640', '5', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 16,700 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=312610" onclick="clickcr(this, 'spe.clist', '312610', '6', event);">에이에프더블류</a></th>
# <td>1,424</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 328 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=900100" onclick="clickcr(this, 'spe.clist', '900100', '7', event);">애머릿지</a></th>
# <td>508</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 117 </td>
# <td>
# <em class="up">
# 				+29.92%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=189330" onclick="clickcr(this, 'spe.clist', '189330', '8', event);">씨이랩</a></th>
# <td>8,950</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 2,060 </td>
# <td>
# <em class="up">
# 				+29.90%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=073570" onclick="clickcr(this, 'spe.clist', '073570', '9', event);">리튬포어스</a></th>
# <td>756</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 174 </td>
# <td>
# <em class="up">
# 				+29.90%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=424760" onclick="clickcr(this, 'spe.clist', '424760', '10', event);">벨로크</a></th>
# <td>2,370</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 545 </td>
# <td>
# <em class="up">
# 				+29.86%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.clist', '078130', '11', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 108 </td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131400" onclick="clickcr(this, 'spe.clist', '131400', '12', event);">이브이첨단소재</a></th>
# <td>2,050</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 471 </td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=051980" onclick="clickcr(this, 'spe.clist', '051980', '13', event);">중앙첨단소재</a></th>
# <td>2,135</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 489 </td>
# <td>
# <em class="up">
# 				+29.71%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=127980" onclick="clickcr(this, 'spe.clist', '127980', '14', event);">화인써키트</a></th>
# <td>6,760</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,500 </td>
# <td>
# <em class="up">
# 				+28.52%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.clist', '336370', '15', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130 </td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab2" style="display:none">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=107640" onclick="clickcr(this, 'spe.clist', '107640', '1', event);">한중엔시에스</a></th>
# <td>72,500</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 16,700 </td>
# <td>
# <em class="up">
# 				+29.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=336370" onclick="clickcr(this, 'spe.clist', '336370', '2', event);">솔루스첨단소재</a></th>
# <td>14,140</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,130 </td>
# <td>
# <em class="up">
# 				+28.43%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=378340" onclick="clickcr(this, 'spe.clist', '378340', '3', event);">필에너지</a></th>
# <td>19,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,270 </td>
# <td>
# <em class="up">
# 				+19.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006400" onclick="clickcr(this, 'spe.clist', '006400', '4', event);">삼성SDI</a></th>
# <td>644,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 106,000 </td>
# <td>
# <em class="up">
# 				+19.70%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=348370" onclick="clickcr(this, 'spe.clist', '348370', '5', event);">엔켐</a></th>
# <td>48,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,200 </td>
# <td>
# <em class="up">
# 				+17.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=171090" onclick="clickcr(this, 'spe.clist', '171090', '6', event);">선익시스템</a></th>
# <td>117,300</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 16,400 </td>
# <td>
# <em class="up">
# 				+16.25%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=469610" onclick="clickcr(this, 'spe.clist', '469610', '7', event);">이노테크</a></th>
# <td>26,550</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,700 </td>
# <td>
# <em class="up">
# 				+16.19%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=443060" onclick="clickcr(this, 'spe.clist', '443060', '8', event);">HD현대마린솔루션</a></th>
# <td>225,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 29,800 </td>
# <td>
# <em class="up">
# 				+15.23%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078600" onclick="clickcr(this, 'spe.clist', '078600', '9', event);">대주전자재료</a></th>
# <td>148,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 18,900 </td>
# <td>
# <em class="up">
# 				+14.54%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=0008Z0" onclick="clickcr(this, 'spe.clist', '0008Z0', '10', event);">에스엔시스</a></th>
# <td>41,050</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,200 </td>
# <td>
# <em class="up">
# 				+14.50%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=009150" onclick="clickcr(this, 'spe.clist', '009150', '11', event);">삼성전기</a></th>
# <td>770,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 90,000 </td>
# <td>
# <em class="up">
# 				+13.24%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=457190" onclick="clickcr(this, 'spe.clist', '457190', '12', event);">이수스페셜티케미컬</a></th>
# <td>126,300</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 14,700 </td>
# <td>
# <em class="up">
# 				+13.17%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006360" onclick="clickcr(this, 'spe.clist', '006360', '13', event);">GS건설</a></th>
# <td>42,750</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,700 </td>
# <td>
# <em class="up">
# 				+12.35%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=323280" onclick="clickcr(this, 'spe.clist', '323280', '14', event);">태성</a></th>
# <td>65,800</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 6,600 </td>
# <td>
# <em class="up">
# 				+11.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=053610" onclick="clickcr(this, 'spe.clist', '053610', '15', event);">프로텍</a></th>
# <td>73,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7,000 </td>
# <td>
# <em class="up">
# 				+10.46%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab3">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=173940" onclick="clickcr(this, 'spe.blist', '173940', '1', event);">에프엔씨엔터</a></th>
# <td>4,140</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -910</td>
# <td>
# <em class="down">
# 				-18.02%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=317120" onclick="clickcr(this, 'spe.blist', '317120', '2', event);">라닉스</a></th>
# <td>2,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -505</td>
# <td>
# <em class="down">
# 				-15.76%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=046970" onclick="clickcr(this, 'spe.blist', '046970', '3', event);">우리로</a></th>
# <td>10,350</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,750</td>
# <td>
# <em class="down">
# 				-14.46%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=338840" onclick="clickcr(this, 'spe.blist', '338840', '4', event);">와이바이오로직스</a></th>
# <td>23,500</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,950</td>
# <td>
# <em class="down">
# 				-14.39%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=215790" onclick="clickcr(this, 'spe.blist', '215790', '5', event);">이노인스트루먼트</a></th>
# <td>2,100</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -345</td>
# <td>
# <em class="down">
# 				-14.11%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=025770" onclick="clickcr(this, 'spe.blist', '025770', '6', event);">한국정보통신</a></th>
# <td>13,680</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,230</td>
# <td>
# <em class="down">
# 				-14.02%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=314130" onclick="clickcr(this, 'spe.blist', '314130', '7', event);">지놈앤컴퍼니</a></th>
# <td>6,070</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -950</td>
# <td>
# <em class="down">
# 				-13.53%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=017900" onclick="clickcr(this, 'spe.blist', '017900', '8', event);">광전자</a></th>
# <td>11,190</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,710</td>
# <td>
# <em class="down">
# 				-13.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=228670" onclick="clickcr(this, 'spe.blist', '228670', '9', event);">레이</a></th>
# <td>8,970</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,360</td>
# <td>
# <em class="down">
# 				-13.17%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=027040" onclick="clickcr(this, 'spe.blist', '027040', '10', event);">서울전자통신</a></th>
# <td>578</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -86</td>
# <td>
# <em class="down">
# 				-12.95%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=356680" onclick="clickcr(this, 'spe.blist', '356680', '11', event);">엑스게이트</a></th>
# <td>14,320</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,120</td>
# <td>
# <em class="down">
# 				-12.90%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=174900" onclick="clickcr(this, 'spe.blist', '174900', '12', event);">앱클론</a></th>
# <td>48,850</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -6,950</td>
# <td>
# <em class="down">
# 				-12.46%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=299660" onclick="clickcr(this, 'spe.blist', '299660', '13', event);">셀리드</a></th>
# <td>3,605</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -505</td>
# <td>
# <em class="down">
# 				-12.29%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=488280" onclick="clickcr(this, 'spe.blist', '488280', '14', event);">에스투더블유</a></th>
# <td>18,980</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,620</td>
# <td>
# <em class="down">
# 				-12.13%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=115500" onclick="clickcr(this, 'spe.blist', '115500', '15', event);">케이씨에스</a></th>
# <td>20,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,800</td>
# <td>
# <em class="down">
# 				-12.12%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_fall.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">하락 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab3" style="display:none">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=338840" onclick="clickcr(this, 'spe.blist', '338840', '1', event);">와이바이오로직스</a></th>
# <td>23,500</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,950</td>
# <td>
# <em class="down">
# 				-14.39%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=488280" onclick="clickcr(this, 'spe.blist', '488280', '2', event);">에스투더블유</a></th>
# <td>19,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,600</td>
# <td>
# <em class="down">
# 				-12.04%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=310210" onclick="clickcr(this, 'spe.blist', '310210', '3', event);">보로노이</a></th>
# <td>307,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -35,500</td>
# <td>
# <em class="down">
# 				-10.36%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=476830" onclick="clickcr(this, 'spe.blist', '476830', '4', event);">알지노믹스</a></th>
# <td>186,200</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -15,800</td>
# <td>
# <em class="down">
# 				-7.82%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=397030" onclick="clickcr(this, 'spe.blist', '397030', '5', event);">에이프릴바이오</a></th>
# <td>58,400</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -4,600</td>
# <td>
# <em class="down">
# 				-7.30%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=124500" onclick="clickcr(this, 'spe.blist', '124500', '6', event);">아이티센글로벌</a></th>
# <td>46,850</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,650</td>
# <td>
# <em class="down">
# 				-7.23%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=476060" onclick="clickcr(this, 'spe.blist', '476060', '7', event);">온코닉테라퓨틱스</a></th>
# <td>22,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,750</td>
# <td>
# <em class="down">
# 				-7.16%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=112040" onclick="clickcr(this, 'spe.blist', '112040', '8', event);">위메이드</a></th>
# <td>24,100</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,850</td>
# <td>
# <em class="down">
# 				-7.13%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=059090" onclick="clickcr(this, 'spe.blist', '059090', '9', event);">미코</a></th>
# <td>22,350</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,700</td>
# <td>
# <em class="down">
# 				-7.07%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=036800" onclick="clickcr(this, 'spe.blist', '036800', '10', event);">나이스정보통신</a></th>
# <td>32,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,450</td>
# <td>
# <em class="down">
# 				-7.05%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=494120" onclick="clickcr(this, 'spe.blist', '494120', '11', event);">큐리오시스</a></th>
# <td>57,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -4,100</td>
# <td>
# <em class="down">
# 				-6.63%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=007340" onclick="clickcr(this, 'spe.blist', '007340', '12', event);">DN오토모티브</a></th>
# <td>38,850</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -2,750</td>
# <td>
# <em class="down">
# 				-6.61%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=389470" onclick="clickcr(this, 'spe.blist', '389470', '13', event);">인벤티지랩</a></th>
# <td>60,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -4,100</td>
# <td>
# <em class="down">
# 				-6.37%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=376900" onclick="clickcr(this, 'spe.blist', '376900', '14', event);">로킷헬스케어</a></th>
# <td>93,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -6,300</td>
# <td>
# <em class="down">
# 				-6.33%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=019170" onclick="clickcr(this, 'spe.blist', '019170', '15', event);">신풍제약</a></th>
# <td>11,920</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -800</td>
# <td>
# <em class="down">
# 				-6.29%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_fall.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">하락 더보기</span></em></a>
# </div>
# <div class="group_type krx_group_type tab4">
# <table class="tbl_home">
# <caption>시가총액 상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems4">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.vlist', '005930', '1', event);">삼성전자</a></th>
# <td>218,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,500</td>
# <td>
# <em class="up">
# 				+1.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=000660" onclick="clickcr(this, 'spe.vlist', '000660', '2', event);">SK하이닉스</a></th>
# <td>1,220,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 54,500</td>
# <td>
# <em class="up">
# 				+4.67%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005935" onclick="clickcr(this, 'spe.vlist', '005935', '3', event);">삼성전자우</a></th>
# <td>150,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,200</td>
# <td>
# <em class="up">
# 				+2.87%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005380" onclick="clickcr(this, 'spe.vlist', '005380', '4', event);">현대차</a></th>
# <td>545,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 18,000</td>
# <td>
# <em class="up">
# 				+3.42%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=373220" onclick="clickcr(this, 'spe.vlist', '373220', '5', event);">LG에너지솔루션</a></th>
# <td>472,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 43,500</td>
# <td>
# <em class="up">
# 				+10.14%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=402340" onclick="clickcr(this, 'spe.vlist', '402340', '6', event);">SK스퀘어</a></th>
# <td>713,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 12,000</td>
# <td>
# <em class="up">
# 				+1.71%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'spe.vlist', '034020', '7', event);">두산에너빌리티</a></th>
# <td>115,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,400</td>
# <td>
# <em class="up">
# 				+3.96%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=207940" onclick="clickcr(this, 'spe.vlist', '207940', '8', event);">삼성바이오로직스</a></th>
# <td>1,596,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 9,000</td>
# <td>
# <em class="down">
# 				-0.56%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=012450" onclick="clickcr(this, 'spe.vlist', '012450', '9', event);">한화에어로스페이스</a></th>
# <td>1,396,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 29,000</td>
# <td>
# <em class="down">
# 				-2.04%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=000270" onclick="clickcr(this, 'spe.vlist', '000270', '10', event);">기아</a></th>
# <td>160,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,800</td>
# <td>
# <em class="up">
# 				+1.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=329180" onclick="clickcr(this, 'spe.vlist', '329180', '11', event);">HD현대중공업</a></th>
# <td>570,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 46,000</td>
# <td>
# <em class="up">
# 				+8.78%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=105560" onclick="clickcr(this, 'spe.vlist', '105560', '12', event);">KB금융</a></th>
# <td>160,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 600</td>
# <td>
# <em class="down">
# 				-0.37%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=009150" onclick="clickcr(this, 'spe.vlist', '009150', '13', event);">삼성전기</a></th>
# <td>769,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 89,000</td>
# <td>
# <em class="up">
# 				+13.09%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006400" onclick="clickcr(this, 'spe.vlist', '006400', '14', event);">삼성SDI</a></th>
# <td>644,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 106,000</td>
# <td>
# <em class="up">
# 				+19.70%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=032830" onclick="clickcr(this, 'spe.vlist', '032830', '15', event);">삼성생명</a></th>
# <td>255,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,500</td>
# <td>
# <em class="up">
# 				+0.59%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_market_sum.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">시가총액 상위 더보기</span></em></a>
# </div>
# <div class="group_type nxt_group_type tab4" style="display:none">
# <table class="tbl_home">
# <caption>시가총액 상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="nxt_topItems4">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.vlist', '005930', '1', event);">삼성전자</a></th>
# <td>218,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,500</td>
# <td>
# <em class="up">
# 				+1.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=000660" onclick="clickcr(this, 'spe.vlist', '000660', '2', event);">SK하이닉스</a></th>
# <td>1,221,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 55,000</td>
# <td>
# <em class="up">
# 				+4.72%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005380" onclick="clickcr(this, 'spe.vlist', '005380', '3', event);">현대차</a></th>
# <td>546,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 19,000</td>
# <td>
# <em class="up">
# 				+3.61%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=373220" onclick="clickcr(this, 'spe.vlist', '373220', '4', event);">LG에너지솔루션</a></th>
# <td>472,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 43,500</td>
# <td>
# <em class="up">
# 				+10.14%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=402340" onclick="clickcr(this, 'spe.vlist', '402340', '5', event);">SK스퀘어</a></th>
# <td>714,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 13,000</td>
# <td>
# <em class="up">
# 				+1.85%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=034020" onclick="clickcr(this, 'spe.vlist', '034020', '6', event);">두산에너빌리티</a></th>
# <td>115,400</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,400</td>
# <td>
# <em class="up">
# 				+3.96%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=207940" onclick="clickcr(this, 'spe.vlist', '207940', '7', event);">삼성바이오로직스</a></th>
# <td>1,596,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 9,000</td>
# <td>
# <em class="down">
# 				-0.56%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=012450" onclick="clickcr(this, 'spe.vlist', '012450', '8', event);">한화에어로스페이스</a></th>
# <td>1,396,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 29,000</td>
# <td>
# <em class="down">
# 				-2.04%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=000270" onclick="clickcr(this, 'spe.vlist', '000270', '9', event);">기아</a></th>
# <td>160,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,800</td>
# <td>
# <em class="up">
# 				+1.78%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=329180" onclick="clickcr(this, 'spe.vlist', '329180', '10', event);">HD현대중공업</a></th>
# <td>569,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45,000</td>
# <td>
# <em class="up">
# 				+8.59%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=105560" onclick="clickcr(this, 'spe.vlist', '105560', '11', event);">KB금융</a></th>
# <td>160,200</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 700</td>
# <td>
# <em class="down">
# 				-0.44%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=009150" onclick="clickcr(this, 'spe.vlist', '009150', '12', event);">삼성전기</a></th>
# <td>770,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 90,000</td>
# <td>
# <em class="up">
# 				+13.24%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006400" onclick="clickcr(this, 'spe.vlist', '006400', '13', event);">삼성SDI</a></th>
# <td>644,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 106,000</td>
# <td>
# <em class="up">
# 				+19.70%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=032830" onclick="clickcr(this, 'spe.vlist', '032830', '14', event);">삼성생명</a></th>
# <td>255,250</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,750</td>
# <td>
# <em class="up">
# 				+0.69%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=028260" onclick="clickcr(this, 'spe.vlist', '028260', '15', event);">삼성물산</a></th>
# <td>304,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 4,000</td>
# <td>
# <em class="up">
# 				+1.33%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/nxt_sise_market_sum.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">시가총액 상위 더보기</span></em></a>
# </div>
# </div>

# %%
# div_data에서 table 태그 중 class의 값이 tbl_home인 태그의 개수가 어떻게 되는가?
len(
    div_data.find_all(
        'table',
        attrs = {
            'class' : 'tbl_home'
        }
    )
)
# Out:
# 8

# %%
# 8개의 테이블을 모두 찾는다
tables = div_data.find_all(
    'table',
    attrs = {
        'class' : 'tbl_home'
    }
)

# %%
tables[0]
# thead는 테이블의 제목 (columns 이름) -> 따로 추출하여 columns 사용
# tbody는 테이블의 데이터 (values) -> 따로 추출해서 values 사용
# Out:
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,396</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 36</td>
# <td>
# <em class="down">
# 				-2.51%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '3', event);">KODEX 2차전지산업레버리지</a></th>
# <td>2,562</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 407</td>
# <td>
# <em class="up">
# 				+18.89%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=047040" onclick="clickcr(this, 'spe.slist', '047040', '4', event);">대우건설</a></th>
# <td>33,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,100</td>
# <td>
# <em class="up">
# 				+18.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.slist', '078130', '5', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 108</td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=065420" onclick="clickcr(this, 'spe.slist', '065420', '6', event);">에스아이리소스</a></th>
# <td>306</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7</td>
# <td>
# <em class="up">
# 				+2.34%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131760" onclick="clickcr(this, 'spe.slist', '131760', '7', event);">파인텍</a></th>
# <td>2,015</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 442</td>
# <td>
# <em class="up">
# 				+28.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=203650" onclick="clickcr(this, 'spe.slist', '203650', '8', event);">드림시큐리티</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 70</td>
# <td>
# <em class="up">
# 				+1.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=184230" onclick="clickcr(this, 'spe.slist', '184230', '9', event);">SGA솔루션즈</a></th>
# <td>1,091</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45</td>
# <td>
# <em class="up">
# 				+4.30%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=530036" onclick="clickcr(this, 'spe.slist', '530036', '10', event);">삼성 인버스 2X WTI원유 선물 ETN</a></th>
# <td>23</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1</td>
# <td>
# <em class="up">
# 				+4.55%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=092220" onclick="clickcr(this, 'spe.slist', '092220', '11', event);">KEC</a></th>
# <td>1,371</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 148</td>
# <td>
# <em class="up">
# 				+12.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.slist', '222080', '12', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,760</td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011930" onclick="clickcr(this, 'spe.slist', '011930', '13', event);">신성이엔지</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 50</td>
# <td>
# <em class="up">
# 				+1.28%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011000" onclick="clickcr(this, 'spe.slist', '011000', '14', event);">진원생명과학</a></th>
# <td>1,418</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 96</td>
# <td>
# <em class="up">
# 				+7.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252710" onclick="clickcr(this, 'spe.slist', '252710', '15', event);">TIGER 200선물인버스2X</a></th>
# <td>192</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 12</td>
# <td>
# <em class="down">
# 				-5.88%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>

# %%
# 반복문에서 사용할 변수명을 그대로 이용하여 1차 작업 (반복 실행 코드를 테스트)
table_data = tables[0]

# %%
# columns에서 사용할 데이터들을 추출 -> table 데이터에서 thead 태그를 추출
head_data = table_data.find('thead')

# %%
head_data
# Out:
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>

# %%
# head_data에서 th 태그를 모두 찾는다
th_list = head_data.find_all('th')
# 각각 th 태그에서 콘텐츠를 추출하여 리스트로 만든다.
# 콘텐츠를 추출하는 방법은 string // get_text()

# case 1
cols = []
for th in th_list:
    cols.append(th.string)
cols
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
# case 2
cols2 = list(
    map(
        lambda x : x.string,
        th_list
    )
)
cols2
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
# case 3
cols3 = [th.string for th in th_list]
cols3
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
# values에서 사용할 데이터들을 추출
body_data = table_data.find('tbody')
body_data
# Out:
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,396</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 36</td>
# <td>
# <em class="down">
# 				-2.51%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '3', event);">KODEX 2차전지산업레버리지</a></th>
# <td>2,562</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 407</td>
# <td>
# <em class="up">
# 				+18.89%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=047040" onclick="clickcr(this, 'spe.slist', '047040', '4', event);">대우건설</a></th>
# <td>33,200</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5,100</td>
# <td>
# <em class="up">
# 				+18.15%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078130" onclick="clickcr(this, 'spe.slist', '078130', '5', event);">국일제지</a></th>
# <td>470</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 108</td>
# <td>
# <em class="up">
# 				+29.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=065420" onclick="clickcr(this, 'spe.slist', '065420', '6', event);">에스아이리소스</a></th>
# <td>306</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 7</td>
# <td>
# <em class="up">
# 				+2.34%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=131760" onclick="clickcr(this, 'spe.slist', '131760', '7', event);">파인텍</a></th>
# <td>2,015</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 442</td>
# <td>
# <em class="up">
# 				+28.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=203650" onclick="clickcr(this, 'spe.slist', '203650', '8', event);">드림시큐리티</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 70</td>
# <td>
# <em class="up">
# 				+1.80%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=184230" onclick="clickcr(this, 'spe.slist', '184230', '9', event);">SGA솔루션즈</a></th>
# <td>1,091</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45</td>
# <td>
# <em class="up">
# 				+4.30%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=530036" onclick="clickcr(this, 'spe.slist', '530036', '10', event);">삼성 인버스 2X WTI원유 선물 ETN</a></th>
# <td>23</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1</td>
# <td>
# <em class="up">
# 				+4.55%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=092220" onclick="clickcr(this, 'spe.slist', '092220', '11', event);">KEC</a></th>
# <td>1,371</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 148</td>
# <td>
# <em class="up">
# 				+12.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=222080" onclick="clickcr(this, 'spe.slist', '222080', '12', event);">씨아이에스</a></th>
# <td>16,310</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,760</td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011930" onclick="clickcr(this, 'spe.slist', '011930', '13', event);">신성이엔지</a></th>
# <td>3,950</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 50</td>
# <td>
# <em class="up">
# 				+1.28%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=011000" onclick="clickcr(this, 'spe.slist', '011000', '14', event);">진원생명과학</a></th>
# <td>1,418</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 96</td>
# <td>
# <em class="up">
# 				+7.26%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252710" onclick="clickcr(this, 'spe.slist', '252710', '15', event);">TIGER 200선물인버스2X</a></th>
# <td>192</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 12</td>
# <td>
# <em class="down">
# 				-5.88%
# 				</em>
# </td>
# </tr>
# </tbody>

# %%
# tr을 모두 찾는다
tr_list = body_data.find_all(
    'tr'
)
len(tr_list)
# Out:
# 15

# %%
# 첫번째 tr 데이터에서 value를 추출 -> 15번 박복
tr = tr_list[0]
tr
# Out:
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>

# %%
# 두개의 태그를 모두 찾는다 ?
row_list = tr.find_all(['th','td'])

# %%
row_list[2]
# Out:
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>

# %%
# row_list에서 콘텐츠 데이터를 추출 -> string, get_text
# get_text() : 태그 안에 모든 콘텐츠를 추출
# string : 콘텐츠 데이터가 한 군데에 존재할때 추출 가능
row_list[2].get_text()
# Out:
# '하락 10'

# %%
value_data = [data.get_text().strip() for data in row_list]
value_data
# Out:
# ['KODEX 200선물인버스2X', '181', '하락 10', '-5.24%']

# %%
values = []

for tr in tr_list:
    row_list = tr.find_all(['th','td'])
    value_data = [data.get_text().strip() for data in row_list]
    # values_data를 이용해서 2차원 데이터 values 생성
    values.append(value_data)
values
# Out:
# [['KODEX 200선물인버스2X', '181', '하락 10', '-5.24%'],
#  ['KODEX 인버스', '1,396', '하락 36', '-2.51%'],
#  ['KODEX 2차전지산업레버리지', '2,562', '상승 407', '+18.89%'],
#  ['대우건설', '33,200', '상승 5,100', '+18.15%'],
#  ['국일제지', '470', '상승 108', '+29.83%'],
#  ['에스아이리소스', '306', '상승 7', '+2.34%'],
#  ['파인텍', '2,015', '상승 442', '+28.10%'],
#  ['드림시큐리티', '3,950', '상승 70', '+1.80%'],
#  ['SGA솔루션즈', '1,091', '상승 45', '+4.30%'],
#  ['삼성 인버스 2X WTI원유 선물 ETN', '23', '상승 1', '+4.55%'],
#  ['KEC', '1,371', '상승 148', '+12.10%'],
#  ['씨아이에스', '16,310', '상승 3,760', '+29.96%'],
#  ['신성이엔지', '3,950', '상승 50', '+1.28%'],
#  ['진원생명과학', '1,418', '상승 96', '+7.26%'],
#  ['TIGER 200선물인버스2X', '192', '하락 12', '-5.88%']]

# %%
import pandas as pd

# %%
pd.DataFrame(values, columns = cols)
# Out:
#                        종목명     현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X     181     하락 10   -5.24%
# 1                KODEX 인버스   1,396     하락 36   -2.51%
# 2         KODEX 2차전지산업레버리지   2,562    상승 407  +18.89%
# 3                     대우건설  33,200  상승 5,100  +18.15%
# 4                     국일제지     470    상승 108  +29.83%
# 5                  에스아이리소스     306      상승 7   +2.34%
# 6                      파인텍   2,015    상승 442  +28.10%
# 7                   드림시큐리티   3,950     상승 70   +1.80%
# 8                  SGA솔루션즈   1,091     상승 45   +4.30%
# 9   삼성 인버스 2X WTI원유 선물 ETN      23      상승 1   +4.55%
# 10                     KEC   1,371    상승 148  +12.10%
# 11                   씨아이에스  16,310  상승 3,760  +29.96%
# 12                   신성이엔지   3,950     상승 50   +1.28%
# 13                  진원생명과학   1,418     상승 96   +7.26%
# 14        TIGER 200선물인버스2X     192     하락 12   -5.88%

# %%
# 8개의 테이블 중 1개 완성
# 8번 반복을 하는 반복문을 생성 -> 각각의 데이터프레임이 생성 -> 각각 다른 전역 변수에 저장( globals()['변수명] )

# 전역변수의 이름을 반복 실행할때마다 변경하기 위한 기본값
vari_num = 1

for table_data in tables:
    # thead를 추출 -> columns 데이터 추출하기 위해서
    head_data = table_data.find('thead')
    # thead 데이터에서 각각 콘텐츠 데이터를 추출하여 리스트화
    cols = [th.string for th in th_list]
    
    # tbody를 추출
    body_data = table_data.find('tbody')
    # 여러개의 행이 존재 -> tr_list를 생성
    tr_list = body_data.find_all('tr')
    # 각각의 tr_data를 추출하여 콘텐츠 데이터를 리스트화 하고 새로운 리스트에 추가
    values = []

    for tr in tr_list:
        row_list = tr.find_all(['th','td'])
        value_data = [data.get_text().strip() for data in row_list]
        # values_data를 이용해서 2차원 데이터 values 생성
        values.append(value_data)
    
    # 데이터프레임을 생성하고 전역변수에 저장
    globals()[f'df{vari_num}'] = pd.DataFrame(values,columns=cols)

    # vari_num을 1 증가시킨다.
    vari_num += 1

# %%
df1
# Out:
#                        종목명     현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X     181     하락 10   -5.24%
# 1                KODEX 인버스   1,396     하락 36   -2.51%
# 2         KODEX 2차전지산업레버리지   2,562    상승 407  +18.89%
# 3                     대우건설  33,200  상승 5,100  +18.15%
# 4                     국일제지     470    상승 108  +29.83%
# 5                  에스아이리소스     306      상승 7   +2.34%
# 6                      파인텍   2,015    상승 442  +28.10%
# 7                   드림시큐리티   3,950     상승 70   +1.80%
# 8                  SGA솔루션즈   1,091     상승 45   +4.30%
# 9   삼성 인버스 2X WTI원유 선물 ETN      23      상승 1   +4.55%
# 10                     KEC   1,371    상승 148  +12.10%
# 11                   씨아이에스  16,310  상승 3,760  +29.96%
# 12                   신성이엔지   3,950     상승 50   +1.28%
# 13                  진원생명과학   1,418     상승 96   +7.26%
# 14        TIGER 200선물인버스2X     192     하락 12   -5.88%

# %%
df2
# Out:
#          종목명      현재가       전일대비      등락률
# 0     오리엔탈정공    8,510     상승 490   +6.11%
# 1       삼성전자  218,000   상승 3,500   +1.63%
# 2       GS건설   42,750   상승 4,700  +12.35%
# 3       성신양회   11,780     상승 750   +6.80%
# 4      삼성중공업   30,000   상승 1,450   +5.08%
# 5       필에너지   19,800   상승 3,270  +19.78%
# 6      애경케미칼   15,200   상승 1,350   +9.75%
# 7      STX엔진   51,000   상승 4,800  +10.39%
# 8    두산에너빌리티  115,400   상승 4,400   +3.96%
# 9     위메이드맥스    6,690     상승 170   +2.61%
# 10  현대지에프홀딩스   14,960     상승 730   +5.13%
# 11   솔루스첨단소재   14,140   상승 3,130  +28.43%
# 12     삼성E&A   51,400   상승 2,100   +4.26%
# 13    한중엔시에스   72,500  상승 16,700  +29.93%
# 14     강원에너지   15,570   상승 1,010   +6.94%

# %%
df3
# Out:
#         종목명      현재가        전일대비      등락률
# 0     정원엔시스    1,297     상한가 299  +29.96%
# 1     씨아이에스   16,310   상한가 3,760  +29.96%
# 2   주성엔지니어링  118,900  상한가 27,400  +29.95%
# 3      킵스파마   10,850   상한가 2,500  +29.94%
# 4    한중엔시에스   72,500  상한가 16,700  +29.93%
# 5   에이에프더블류    1,424     상한가 328  +29.93%
# 6      애머릿지      508     상한가 117  +29.92%
# 7       씨이랩    8,950   상한가 2,060  +29.90%
# 8     리튬포어스      756     상한가 174  +29.90%
# 9       벨로크    2,370     상한가 545  +29.86%
# 10     국일제지      470     상한가 108  +29.83%
# 11  이브이첨단소재    2,050     상한가 471  +29.83%
# 12   중앙첨단소재    2,135     상한가 489  +29.71%
# 13    화인써키트    6,760    상승 1,500  +28.52%
# 14  솔루스첨단소재   14,140    상승 3,130  +28.43%

# %%
df4
# Out:
#           종목명      현재가        전일대비      등락률
# 0      한중엔시에스   72,500  상한가 16,700  +29.93%
# 1     솔루스첨단소재   14,140    상승 3,130  +28.43%
# 2        필에너지   19,800    상승 3,270  +19.78%
# 3       삼성SDI  644,000  상승 106,000  +19.70%
# 4          엔켐   48,950    상승 7,200  +17.25%
# 5       선익시스템  117,300   상승 16,400  +16.25%
# 6        이노테크   26,550    상승 3,700  +16.19%
# 7   HD현대마린솔루션  225,500   상승 29,800  +15.23%
# 8      대주전자재료  148,900   상승 18,900  +14.54%
# 9       에스엔시스   41,050    상승 5,200  +14.50%
# 10       삼성전기  770,000   상승 90,000  +13.24%
# 11  이수스페셜티케미컬  126,300   상승 14,700  +13.17%
# 12       GS건설   42,750    상승 4,700  +12.35%
# 13         태성   65,800    상승 6,600  +11.15%
# 14        프로텍   73,900    상승 7,000  +10.46%

# %%
df5
# Out:
#          종목명     현재가       전일대비      등락률
# 0     에프엔씨엔터   4,140    하락 -910  -18.02%
# 1        라닉스   2,700    하락 -505  -15.76%
# 2        우리로  10,350  하락 -1,750  -14.46%
# 3   와이바이오로직스  23,500  하락 -3,950  -14.39%
# 4   이노인스트루먼트   2,100    하락 -345  -14.11%
# 5     한국정보통신  13,680  하락 -2,230  -14.02%
# 6     지놈앤컴퍼니   6,070    하락 -950  -13.53%
# 7        광전자  11,190  하락 -1,710  -13.26%
# 8         레이   8,970  하락 -1,360  -13.17%
# 9     서울전자통신     578     하락 -86  -12.95%
# 10     엑스게이트  14,320  하락 -2,120  -12.90%
# 11       앱클론  48,850  하락 -6,950  -12.46%
# 12       셀리드   3,605    하락 -505  -12.29%
# 13    에스투더블유  18,980  하락 -2,620  -12.13%
# 14     케이씨에스  20,300  하락 -2,800  -12.12%

# %%
df6
# Out:
#          종목명      현재가        전일대비      등락률
# 0   와이바이오로직스   23,500   하락 -3,950  -14.39%
# 1     에스투더블유   19,000   하락 -2,600  -12.04%
# 2       보로노이  307,000  하락 -35,500  -10.36%
# 3      알지노믹스  186,200  하락 -15,800   -7.82%
# 4    에이프릴바이오   58,400   하락 -4,600   -7.30%
# 5    아이티센글로벌   46,850   하락 -3,650   -7.23%
# 6   온코닉테라퓨틱스   22,700   하락 -1,750   -7.16%
# 7       위메이드   24,100   하락 -1,850   -7.13%
# 8         미코   22,350   하락 -1,700   -7.07%
# 9    나이스정보통신   32,300   하락 -2,450   -7.05%
# 10     큐리오시스   57,700   하락 -4,100   -6.63%
# 11   DN오토모티브   38,850   하락 -2,750   -6.61%
# 12     인벤티지랩   60,300   하락 -4,100   -6.37%
# 13    로킷헬스케어   93,300   하락 -6,300   -6.33%
# 14      신풍제약   11,920     하락 -800   -6.29%

# %%
df7
# Out:
#           종목명        현재가        전일대비      등락률
# 0        삼성전자    218,000    상승 3,500   +1.63%
# 1      SK하이닉스  1,220,500   상승 54,500   +4.67%
# 2       삼성전자우    150,600    상승 4,200   +2.87%
# 3         현대차    545,000   상승 18,000   +3.42%
# 4    LG에너지솔루션    472,500   상승 43,500  +10.14%
# 5       SK스퀘어    713,000   상승 12,000   +1.71%
# 6     두산에너빌리티    115,400    상승 4,400   +3.96%
# 7    삼성바이오로직스  1,596,000    하락 9,000   -0.56%
# 8   한화에어로스페이스  1,396,000   하락 29,000   -2.04%
# 9          기아    160,200    상승 2,800   +1.78%
# 10    HD현대중공업    570,000   상승 46,000   +8.78%
# 11       KB금융    160,300      하락 600   -0.37%
# 12       삼성전기    769,000   상승 89,000  +13.09%
# 13      삼성SDI    644,000  상승 106,000  +19.70%
# 14       삼성생명    255,000    상승 1,500   +0.59%

# %%
df8
# Out:
#           종목명        현재가        전일대비      등락률
# 0        삼성전자    218,000    상승 3,500   +1.63%
# 1      SK하이닉스  1,221,000   상승 55,000   +4.72%
# 2         현대차    546,000   상승 19,000   +3.61%
# 3    LG에너지솔루션    472,500   상승 43,500  +10.14%
# 4       SK스퀘어    714,000   상승 13,000   +1.85%
# 5     두산에너빌리티    115,400    상승 4,400   +3.96%
# 6    삼성바이오로직스  1,596,000    하락 9,000   -0.56%
# 7   한화에어로스페이스  1,396,000   하락 29,000   -2.04%
# 8          기아    160,200    상승 2,800   +1.78%
# 9     HD현대중공업    569,000   상승 45,000   +8.59%
# 10       KB금융    160,200      하락 700   -0.44%
# 11       삼성전기    770,000   상승 90,000  +13.24%
# 12      삼성SDI    644,000  상승 106,000  +19.70%
# 13       삼성생명    255,250    상승 1,750   +0.69%
# 14       삼성물산    304,000    상승 4,000   +1.33%

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\lovek\appdata\local\programs\python\python311\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\lovek\appdata\local\programs\python\python311\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\lovek\appdata\local\programs\python\python311\lib\site-packages (from html5lib) (0.5.1)
# WARNING: Ignoring invalid distribution ~yproj (C:\Users\lovek\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yproj (C:\Users\lovek\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yproj (C:\Users\lovek\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
res = requests.get('https://finance.naver.com')

# %%
type(str(div_data))
# Out:
# str

# %%
# html 문서 안에서 table 안에 데이터를 크롤링 하려면
# pandas 호출
dfs = pd.read_html(str(div_data)) # list안에 원소들이 데이터프레임
# Out:
# C:\Users\lovek\AppData\Local\Temp\ipykernel_24264\3616710996.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(div_data)) # list안에 원소들이 데이터프레임

# %%
dfs[1]
# Out:
#          종목명     현재가       전일대비      등락률
# 0     오리엔탈정공    8510     상승 490   +6.11%
# 1       삼성전자  218000   상승 3,500   +1.63%
# 2       GS건설   42750   상승 4,700  +12.35%
# 3       성신양회   11780     상승 750   +6.80%
# 4      삼성중공업   30000   상승 1,450   +5.08%
# 5       필에너지   19800   상승 3,270  +19.78%
# 6      애경케미칼   15200   상승 1,350   +9.75%
# 7      STX엔진   51000   상승 4,800  +10.39%
# 8    두산에너빌리티  115400   상승 4,400   +3.96%
# 9     위메이드맥스    6690     상승 170   +2.61%
# 10  현대지에프홀딩스   14960     상승 730   +5.13%
# 11   솔루스첨단소재   14140   상승 3,130  +28.43%
# 12     삼성E&A   51400   상승 2,100   +4.26%
# 13    한중엔시에스   72500  상승 16,700  +29.93%
# 14     강원에너지   15570   상승 1,010   +6.94%
